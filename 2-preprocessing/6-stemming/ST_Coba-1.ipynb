# %%
import pandas as pd
import nltk
import numpy as np
import Sastrawi

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

def load_data():
    data = pd.read_csv('sw-semua.csv')
    return data

tweet_df = load_data()
tweet_df
# Out:
#                                                  Tweets  \
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# 1         jangan ujan woyy shopeefood gua belom sampe 😭
# 2     Gw masih kepikiran that random cheesecake I fo...
# 3                  @urlovelymeow Coba cek di shopeefood
# 4     @wannayuuu @bdngfess Sok kirim aja kalo mau mh...
# ...                                                 ...
# 5503  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5504  Geh! Aku mau daftarin ayahku di shopeefood as ...
# 5505      alhamdulillah di rancaekek udh ada shopeefood
# 5506  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5507  @RacunBelanja https://t.co/siFXa9KDnE\n\nLumay...
#
#                                            Case_Folding  \
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# 1         jangan ujan woyy shopeefood gua belom sampe 😭
# 2     gw masih kepikiran that random cheesecake i fo...
# 3                  @urlovelymeow coba cek di shopeefood
# ...

# %%
df = pd.DataFrame(tweet_df[['Tweets', 'Case_Folding', 'Clean_Data', 'Tweet_Normal', 'Tanpa_StopWords']])

# %%
# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

df['Stemming'] = df['Tanpa_StopWords'].apply(lambda x : ([stemmer.stem(y) for y in x.split()]))

# %%
df
# Out:
#                                                  Tweets  \
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# 1         jangan ujan woyy shopeefood gua belom sampe 😭
# 2     Gw masih kepikiran that random cheesecake I fo...
# 3                  @urlovelymeow Coba cek di shopeefood
# 4     @wannayuuu @bdngfess Sok kirim aja kalo mau mh...
# ...                                                 ...
# 5503  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5504  Geh! Aku mau daftarin ayahku di shopeefood as ...
# 5505      alhamdulillah di rancaekek udh ada shopeefood
# 5506  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5507  @RacunBelanja https://t.co/siFXa9KDnE\n\nLumay...
#
#                                            Case_Folding  \
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# 1         jangan ujan woyy shopeefood gua belom sampe 😭
# 2     gw masih kepikiran that random cheesecake i fo...
# 3                  @urlovelymeow coba cek di shopeefood
# ...

# %%
df.to_csv('stemming-semua.csv',encoding='utf8', index=False)

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import Sastrawi

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

df= pd.read_csv('Stemming.csv')
df.columns = ['Tweets', 'Case_Folding', 'Data_Cleaning', 'without_stopwords', 'Tokenizing']

df.drop(['without_stopwords', 'Tokenizing'], axis=1, inplace=True)

# %%
df
# Out:
#                                                Tweets  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @Mundur41149832 shopeefood klau ngakpunya shop...
# 2   Spaghetti Aglio E Olio biasa? bukan! spaghetti...
# 3   Ngakak + malu banget, masa pesen shopeefood ki...
# 4   barangkali ada yg tinggal di sekitar daerah pa...
# ..                                                ...
# 95  Abis order shopeefood buat ortu trus mau order...
# 96  @kertas_angin @ShopeeID @shopeefood_id Trus ke...
# 97  Emg ada ya bapak bapak namanya Emma? Heran ih ...
# 98  Nasi Goreng Tiga De Nok - Palmerah sekarang ad...
# 99                 ajarin gimana cara make shopeefood
#
#                                          Case_Folding  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @mundur41149832 shopeefood klau ngakpunya shop...
# 2   spaghetti aglio e olio biasa? bukan! spaghetti...
# 3   ngakak + malu banget, masa pesen shopeefood ki...
# ...

# %%
stop = stopwords.words('indonesian')
df['without_stopwords']= df['Data_Cleaning'].apply(lambda x: ' '.join([item for item in x if item not in stop]))
df['without_stopwords'] = df['Data_Cleaning'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

df['Stemmed']= df['without_stopwords'].apply(lambda x : [stemmer.stem(y) for y in x])

# %%
df
# Out:
#                                                Tweets  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @Mundur41149832 shopeefood klau ngakpunya shop...
# 2   Spaghetti Aglio E Olio biasa? bukan! spaghetti...
# 3   Ngakak + malu banget, masa pesen shopeefood ki...
# 4   barangkali ada yg tinggal di sekitar daerah pa...
# ..                                                ...
# 95  Abis order shopeefood buat ortu trus mau order...
# 96  @kertas_angin @ShopeeID @shopeefood_id Trus ke...
# 97  Emg ada ya bapak bapak namanya Emma? Heran ih ...
# 98  Nasi Goreng Tiga De Nok - Palmerah sekarang ad...
# 99                 ajarin gimana cara make shopeefood
#
#                                          Case_Folding  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @mundur41149832 shopeefood klau ngakpunya shop...
# 2   spaghetti aglio e olio biasa? bukan! spaghetti...
# 3   ngakak + malu banget, masa pesen shopeefood ki...
# ...
