# %%
import pandas as pd 
import numpy as np
import string 
import re #regex library

# %%
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# %%
def load_data():
    data = pd.read_csv('datacleaning_coba.csv')
    return data

# %%
tweet_df = load_data()
tweet_df.head(340)
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                 Created_At  \
# 0             0             0               0                        NaN
# 1             1             1               1  2021-10-23 06:55:05+00:00
# 2             2             2               2  2021-10-23 06:52:15+00:00
# 3             3             3               3  2021-10-23 06:32:42+00:00
# 4             4             4               4  2021-10-23 06:17:33+00:00
# ..          ...           ...             ...                        ...
# 335         335           335             335  2021-10-21 10:27:43+00:00
# 336         336           336             336  2021-10-21 10:23:24+00:00
# 337         337           337             337  2021-10-21 10:22:48+00:00
# 338         338           338             338  2021-10-21 10:09:19+00:00
# 339         339           339             339  2021-10-21 10:08:55+00:00
#
#                                                 Tweets
# ...

# %%
df  = pd.DataFrame(tweet_df[['Created_At', 'Tweets']])

# %%
def remove(tweet):
    #remove angka
    tweet = re.sub('[0-9]+', '', tweet)
    
    # remove tab, new line, ans back slice
    tweet = tweet.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
 
    # remove non ASCII (emoticon, chinese word, .etc)
    tweet = tweet.encode('ascii', 'replace').decode('ascii')
    
    # remove mention, link, hashtag
    tweet = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", tweet).split())

    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    
    #remove punctuation
    tweet = tweet.translate(str.maketrans("","",string.punctuation))
    
    #remove whitespace leading & trailing
    tweet = tweet.strip()
    
    #remove multiple whitespace into single whitespace
    tweet = re.sub('\s+',' ',tweet)

    return tweet
df['remove_http'].apply(lambda x: remove(x))
# Out:
# 0                                                 tweets
# 1                      b syukur done beli via shopeefood
# 2      bkesel bgt beli shopeefood lupa nyalain diskon...
# 3      b nasi padang lauk ayam sama sayur es teh cuma...
# 4      b shopeefood klau ngakpunya shopepay gabisa da...
#                              ...
# 335    bke circle k jalan kaki cuma mnt tp ak pesen l...
# 336    bnasi goreng tiga de nok palmerah sekarang ada...
# 337    b masih ada nih diskon di shopeefood nugget rb...
# 338    bkenapa deh shopeefood makanannya ga ada decs ...
# 339    bguis yuk diorder cemilannyaxexxbaxefxbxf menu...
# Name: remove_http, Length: 340, dtype: object

# %%
df
# Out:
#                     Created_At  \
# 0                          NaN
# 1    2021-10-23 06:55:05+00:00
# 2    2021-10-23 06:52:15+00:00
# 3    2021-10-23 06:32:42+00:00
# 4    2021-10-23 06:17:33+00:00
# ..                         ...
# 335  2021-10-21 10:27:43+00:00
# 336  2021-10-21 10:23:24+00:00
# 337  2021-10-21 10:22:48+00:00
# 338  2021-10-21 10:09:19+00:00
# 339  2021-10-21 10:08:55+00:00
#
#                                                 Tweets  \
# 0                                               tweets
# 1    b'@jibrilss15 @jibrilbangi syukur... done beli...
# 2    b'kesel bgt beli shopeefood lupa nyalain disko...
# 3    b'2 nasi padang lauk ayam sama sayur + es teh ...
# 4    b'@mundur41149832 shopeefood klau ngakpunya sh...
# ..                                                 ...
# 335  b'ke circle k jalan kaki cuma 5 mnt tp ak pese...
# 336  b'nasi goreng tiga de nok - palmerah sekarang ...
# 337  b'@balebengong #kamisbisnis\nmasih ada nih dis...
# ...

# %%
def remove(tweet):
    #remove angka
    tweet = re.sub('[0-9]+', '', tweet)
    
    # remove tab, new line, ans back slice
    tweet = tweet.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
 
    # remove non ASCII (emoticon, chinese word, .etc)
    tweet = tweet.encode('ascii', 'replace').decode('ascii')
    
    # remove incomplete URL
    tweet = re.sub(r"http\S+", "", tweet)

    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    
    #remove punctuation
    tweet = tweet.translate(str.maketrans("","",string.punctuation))
    
    #remove whitespace leading & trailing
    tweet = tweet.strip()
    
    #remove multiple whitespace into single whitespace
    tweet = re.sub('\s+',' ',tweet)

    return tweet
df['remove_http'] = df['remove_user'].apply(lambda x: remove(x))

# %%
df
# Out:
#                     Created_At  \
# 0                          NaN
# 1    2021-10-23 06:55:05+00:00
# 2    2021-10-23 06:52:15+00:00
# 3    2021-10-23 06:32:42+00:00
# 4    2021-10-23 06:17:33+00:00
# ..                         ...
# 335  2021-10-21 10:27:43+00:00
# 336  2021-10-21 10:23:24+00:00
# 337  2021-10-21 10:22:48+00:00
# 338  2021-10-21 10:09:19+00:00
# 339  2021-10-21 10:08:55+00:00
#
#                                                 Tweets  \
# 0                                               tweets
# 1    b'@jibrilss15 @jibrilbangi syukur... done beli...
# 2    b'kesel bgt beli shopeefood lupa nyalain disko...
# 3    b'2 nasi padang lauk ayam sama sayur + es teh ...
# 4    b'@mundur41149832 shopeefood klau ngakpunya sh...
# ..                                                 ...
# 335  b'ke circle k jalan kaki cuma 5 mnt tp ak pese...
# 336  b'nasi goreng tiga de nok - palmerah sekarang ...
# 337  b'@balebengong #kamisbisnis\nmasih ada nih dis...
# ...

# %%
def remove(tweet):
    #remove angka
    tweet = re.sub('[0-9]+', '', tweet)
    
    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)
 
    # remove old style retweet text "RT"
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    
    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    return tweet
df['remove_http'] = df['remove_user'].apply(lambda x: remove(x))

# %%
def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

# %%
TWEET_DATA['Tweet_Special'] = TWEET_DATA['Tweet_Special'].apply(remove_tweet_special)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tweet_Special'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(TWEET_DATA['Tweets'].head(340))
# Out:
# 0                                                 tweets
# 1                  b' syukur... done beli via shopeefood
# 2      b'kesel bgt beli shopeefood lupa nyalain disko...
# 3      b'2 nasi padang lauk ayam sama sayur + es teh ...
# 4      b' shopeefood klau ngakpunya shopepay gabisa d...
#                              ...
# 335    b'ke circle k jalan kaki cuma 5 mnt tp ak pese...
# 336    b'nasi goreng tiga de nok - palmerah sekarang ...
# 337    b' masih ada nih diskon di shopeefood. nugget ...
# 338    b'kenapa deh shopeefood makanannya ga ada decs...
# 339    b'guis yuk diorder cemilannyaxe2x98xbaxefxb8x8...
# Name: Tweets, Length: 340, dtype: object

# %%
def remove_tweet_special()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Data Cleaning'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
