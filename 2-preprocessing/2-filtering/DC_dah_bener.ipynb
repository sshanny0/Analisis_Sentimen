# %%
import pandas as pd 
import numpy as np
import string 
import re #regex library

# %%
def load_data():
    data = pd.read_csv('casefolding-semua.csv')
    return data

# %%
tweet_df = load_data()
tweet_df
# Out:
#       Unnamed: 0                                             Tweets  \
# 0              0  shopeefood ini ga bisa ngasih tip buat driver ...
# 1              1      jangan ujan woyy shopeefood gua belom sampe 😭
# 2              2  Gw masih kepikiran that random cheesecake I fo...
# 3              3               @urlovelymeow Coba cek di shopeefood
# 4              4  @wannayuuu @bdngfess Sok kirim aja kalo mau mh...
# ...          ...                                                ...
# 5503        5503  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5504        5504  Geh! Aku mau daftarin ayahku di shopeefood as ...
# 5505        5505      alhamdulillah di rancaekek udh ada shopeefood
# 5506        5506  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5507        5507  @RacunBelanja https://t.co/siFXa9KDnE\n\nLumay...
#
#                                            Case_Folding
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# ...

# %%
df  = pd.DataFrame(tweet_df[['Tweets', 'Case_Folding']])

# %%
def remove(tweet):
    
    #remove one char
    tweet = re.sub(r"\b[a-zA-Z]\b", "", tweet)

    #remove angka
    tweet = re.sub('[0-9]+', '', tweet)
    
    # remove tab, new line, ans back slice
    tweet = tweet.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
 
    # remove non ASCII (emoticon, chinese word, .etc)
    tweet = tweet.encode('ascii', 'replace').decode('ascii')
    
    # remove mention, link, hashtag
    tweet = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", tweet).split())

    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    
    #remove punctuation
    tweet = tweet.translate(str.maketrans("","",string.punctuation))
    
    #remove whitespace leading & trailing
    tweet = tweet.strip()
    
    #remove multiple whitespace into single whitespace
    tweet = re.sub('\s+',' ',tweet)

    return tweet

df["Clean_Data"] = df["Case_Folding"].apply(remove)

# %%
df
# Out:
#                                                  Tweets  \
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# 1         jangan ujan woyy shopeefood gua belom sampe 😭
# 2     Gw masih kepikiran that random cheesecake I fo...
# 3                  @urlovelymeow Coba cek di shopeefood
# 4     @wannayuuu @bdngfess Sok kirim aja kalo mau mh...
# ...                                                 ...
# 5503  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5504  Geh! Aku mau daftarin ayahku di shopeefood as ...
# 5505      alhamdulillah di rancaekek udh ada shopeefood
# 5506  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5507  @RacunBelanja https://t.co/siFXa9KDnE\n\nLumay...
#
#                                            Case_Folding  \
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# 1         jangan ujan woyy shopeefood gua belom sampe 😭
# 2     gw masih kepikiran that random cheesecake i fo...
# 3                  @urlovelymeow coba cek di shopeefood
# ...

# %%
df.to_csv('dc-semua.csv',encoding='utf8', index=False)
