# %%
import pandas as pd

# %%
def load_data():
    data = pd.read_csv('SW_ShopeeFood.csv')
    return data

# %%
tweet_df = load_data()
tweet_df.head(100)

df  = pd.DataFrame(tweet_df[['Tweets', 'Case_Folding', 'Data_Cleaning', 'Tokenizing']])

# %%
df.drop(['Tweets', 'Case_Folding', 'Data_Cleaning'], axis=1, inplace=True)

# %%
df
# Out:
#                                            Tokenizing
# 0   ['nasi', 'padang', 'lauk', 'ayam', 'sama', 'sa...
# 1   ['shopeefood', 'klau', 'ngakpunya', 'shopepay'...
# 2   ['spaghetti', 'aglio', 'e', 'olio', 'biasa', '...
# 3   ['ngakak', 'malu', 'banget', 'masa', 'pesen', ...
# 4   ['barangkali', 'ada', 'yg', 'tinggal', 'di', '...
# ..                                                ...
# 95  ['abis', 'order', 'shopeefood', 'buat', 'ortu'...
# 96  ['angin', 'id', 'trus', 'kelanjutannya', 'gima...
# 97  ['emg', 'ada', 'ya', 'bapak', 'bapak', 'namany...
# 98  ['nasi', 'goreng', 'tiga', 'de', 'nok', 'palme...
# 99  ['ajarin', 'gimana', 'cara', 'make', 'shopeefo...
#
# [100 rows x 1 columns]

# %%
df.to_csv('SW_Only_ShopeeFood.csv')

# %%
import nltk

from nltk.corpus import stopwords

# %%
with open('SW_Only_ShopeeFood.csv', 'r', encoding='utf-8') as f:
    stop_words = f.read().strip().split(" ")
stop_words
# Out:
# [',Tokenizing\n0,"[\'nasi\',',
#  "'padang',",
#  "'lauk',",
#  "'ayam',",
#  "'sama',",
#  "'sayur',",
#  "'es',",
#  "'teh',",
#  "'cuman',",
#  "'k',",
#  "'shopeefood',",
#  "'aku',",
#  "'padamuuu',",
#  '\'huhuhuu\']"\n1,"[\'shopeefood\',',
#  "'klau',",
#  "'ngakpunya',",
#  "'shopepay',",
#  "'gabisa',",
#  "'dapet',",
#  "'voucernya',",
#  '\'kan\']"\n2,"[\'spaghetti\',',
#  "'aglio',",
#  "'e',",
#  "'olio',",
#  "'biasa',",
#  "'bukan',",
#  "'spaghetti',",
#  "'masakane',",
#  "'simbah',",
#  "'sing',",
#  "'iki',",
#  "'dimasak',",
#  "'pake',",
#  "'bumbu',",
#  "'roa',",
#  "'cocok',",
#  "'nggo',",
#  "'ilat',",
#  "'indonesia',",
#  "'dijamin',",
#  "'nampolll',",
#  "'ada',",
#  "'di',",
#  "'warung',",
#  "'mbah',",
#  "'sambat',",
#  "'bisa',",
#  "'dine',",
#  "'intake',",
#  "'away',",
#  "'bisa',",
#  "'juga',",
#  "'pesen',",
#  "'lewat',",
#  '\'gofoodshopeefood\']"\n3,"[\'ngakak\',',
#  "'malu',",
#  "'banget',",
#  "'masa',",
#  "'pesen',",
# ...

# %%
words = set(stopwords.words("indonesian"))
filtered = [w for w in stop_words if not w in words]

# %%
filtered
# Out:
# [',Tokenizing\n0,"[\'nasi\',',
#  "'padang',",
#  "'lauk',",
#  "'ayam',",
#  "'sama',",
#  "'sayur',",
#  "'es',",
#  "'teh',",
#  "'cuman',",
#  "'k',",
#  "'shopeefood',",
#  "'aku',",
#  "'padamuuu',",
#  '\'huhuhuu\']"\n1,"[\'shopeefood\',',
#  "'klau',",
#  "'ngakpunya',",
#  "'shopepay',",
#  "'gabisa',",
#  "'dapet',",
#  "'voucernya',",
#  '\'kan\']"\n2,"[\'spaghetti\',',
#  "'aglio',",
#  "'e',",
#  "'olio',",
#  "'biasa',",
#  "'bukan',",
#  "'spaghetti',",
#  "'masakane',",
#  "'simbah',",
#  "'sing',",
#  "'iki',",
#  "'dimasak',",
#  "'pake',",
#  "'bumbu',",
#  "'roa',",
#  "'cocok',",
#  "'nggo',",
#  "'ilat',",
#  "'indonesia',",
#  "'dijamin',",
#  "'nampolll',",
#  "'ada',",
#  "'di',",
#  "'warung',",
#  "'mbah',",
#  "'sambat',",
#  "'bisa',",
#  "'dine',",
#  "'intake',",
#  "'away',",
#  "'bisa',",
#  "'juga',",
#  "'pesen',",
#  "'lewat',",
#  '\'gofoodshopeefood\']"\n3,"[\'ngakak\',',
#  "'malu',",
#  "'banget',",
#  "'masa',",
#  "'pesen',",
# ...

# %%
list_stopwords = stopwords.words('indonesian')

txt_stopword = pd.read_csv("SW_ShopeeFood.csv", names= ["Data_Cleaning"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["Data_Cleaning"][0].split(' '))

list_stopwords = set(list_stopwords)

# %%
list_stopwords
# Out:
# {'Tokenizing',
#  'ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
# ...

# %%
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

tweet_df['StopWords'] = tweet_df['Data_Cleaning'].apply(stopwords_removal) 


tweet_df
# Out:
#     Unnamed: 0                                             Tweets  \
# 0            0  2 nasi padang lauk ayam sama sayur + es teh cu...
# 1            1  @Mundur41149832 shopeefood klau ngakpunya shop...
# 2            2  Spaghetti Aglio E Olio biasa? bukan! spaghetti...
# 3            3  Ngakak + malu banget, masa pesen shopeefood ki...
# 4            4  barangkali ada yg tinggal di sekitar daerah pa...
# ..         ...                                                ...
# 95          95  Abis order shopeefood buat ortu trus mau order...
# 96          96  @kertas_angin @ShopeeID @shopeefood_id Trus ke...
# 97          97  Emg ada ya bapak bapak namanya Emma? Heran ih ...
# 98          98  Nasi Goreng Tiga De Nok - Palmerah sekarang ad...
# 99          99                 ajarin gimana cara make shopeefood
#
#                                          Case_Folding  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @mundur41149832 shopeefood klau ngakpunya shop...
# ...
