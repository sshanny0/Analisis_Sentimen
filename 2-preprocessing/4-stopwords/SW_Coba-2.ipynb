# %%
import pandas as pd
import nltk

from nltk.corpus import stopwords
stop_words=stopwords.words('indonesian')
stop_words.extend(["yg", "dg", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh',
                       '&amp', 'yah', 'klau'])

df = pd.read_csv('SW_ShopeeFood.csv') 

df.columns = ['Tweets', 'Case_Folding', 'Data_Cleaning', 'Tokenizing']

df['without_stopwords'] = df['Data_Cleaning'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
df
# Out:
#                                                Tweets  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @Mundur41149832 shopeefood klau ngakpunya shop...
# 2   Spaghetti Aglio E Olio biasa? bukan! spaghetti...
# 3   Ngakak + malu banget, masa pesen shopeefood ki...
# 4   barangkali ada yg tinggal di sekitar daerah pa...
# ..                                                ...
# 95  Abis order shopeefood buat ortu trus mau order...
# 96  @kertas_angin @ShopeeID @shopeefood_id Trus ke...
# 97  Emg ada ya bapak bapak namanya Emma? Heran ih ...
# 98  Nasi Goreng Tiga De Nok - Palmerah sekarang ad...
# 99                 ajarin gimana cara make shopeefood
#
#                                          Case_Folding  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @mundur41149832 shopeefood klau ngakpunya shop...
# 2   spaghetti aglio e olio biasa? bukan! spaghetti...
# 3   ngakak + malu banget, masa pesen shopeefood ki...
# ...

# %%
df.drop(['Tokenizing'], axis=1, inplace=True)

# %%
df
# Out:
#                                                Tweets  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @Mundur41149832 shopeefood klau ngakpunya shop...
# 2   Spaghetti Aglio E Olio biasa? bukan! spaghetti...
# 3   Ngakak + malu banget, masa pesen shopeefood ki...
# 4   barangkali ada yg tinggal di sekitar daerah pa...
# ..                                                ...
# 95  Abis order shopeefood buat ortu trus mau order...
# 96  @kertas_angin @ShopeeID @shopeefood_id Trus ke...
# 97  Emg ada ya bapak bapak namanya Emma? Heran ih ...
# 98  Nasi Goreng Tiga De Nok - Palmerah sekarang ad...
# 99                 ajarin gimana cara make shopeefood
#
#                                          Case_Folding  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @mundur41149832 shopeefood klau ngakpunya shop...
# 2   spaghetti aglio e olio biasa? bukan! spaghetti...
# 3   ngakak + malu banget, masa pesen shopeefood ki...
# ...

# %%
from nltk.tokenize import word_tokenize
df['Tokenizing'] = df['without_stopwords'].apply(word_tokenize)
df
# Out:
#                                                Tweets  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @Mundur41149832 shopeefood klau ngakpunya shop...
# 2   Spaghetti Aglio E Olio biasa? bukan! spaghetti...
# 3   Ngakak + malu banget, masa pesen shopeefood ki...
# 4   barangkali ada yg tinggal di sekitar daerah pa...
# ..                                                ...
# 95  Abis order shopeefood buat ortu trus mau order...
# 96  @kertas_angin @ShopeeID @shopeefood_id Trus ke...
# 97  Emg ada ya bapak bapak namanya Emma? Heran ih ...
# 98  Nasi Goreng Tiga De Nok - Palmerah sekarang ad...
# 99                 ajarin gimana cara make shopeefood
#
#                                          Case_Folding  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @mundur41149832 shopeefood klau ngakpunya shop...
# 2   spaghetti aglio e olio biasa? bukan! spaghetti...
# 3   ngakak + malu banget, masa pesen shopeefood ki...
# ...

# %%
df.to_csv('SW_ShopeeFood_D.csv',encoding='utf8', index=False)

# %%
import pandas as pd
import nltk

from nltk.corpus import stopwords
stop_words=stopwords.words('indonesian')

df = pd.read_csv('SW_Only_ShopeeFood.csv') 

tokenizing = df["Tokenizing"].tolist()

df['without_stopwords'] = df['Tokenizing'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
df
# Out:
#     Unnamed: 0                                         Tokenizing  \
# 0            0  ['nasi', 'padang', 'lauk', 'ayam', 'sama', 'sa...
# 1            1  ['shopeefood', 'klau', 'ngakpunya', 'shopepay'...
# 2            2  ['spaghetti', 'aglio', 'e', 'olio', 'biasa', '...
# 3            3  ['ngakak', 'malu', 'banget', 'masa', 'pesen', ...
# 4            4  ['barangkali', 'ada', 'yg', 'tinggal', 'di', '...
# ..         ...                                                ...
# 95          95  ['abis', 'order', 'shopeefood', 'buat', 'ortu'...
# 96          96  ['angin', 'id', 'trus', 'kelanjutannya', 'gima...
# 97          97  ['emg', 'ada', 'ya', 'bapak', 'bapak', 'namany...
# 98          98  ['nasi', 'goreng', 'tiga', 'de', 'nok', 'palme...
# 99          99  ['ajarin', 'gimana', 'cara', 'make', 'shopeefo...
#
#                                     without_stopwords
# 0   ['nasi', 'padang', 'lauk', 'ayam', 'sama', 'sa...
# 1   ['shopeefood', 'klau', 'ngakpunya', 'shopepay'...
# ...

# %%
import pandas as pd
import nltk

from nltk.corpus import stopwords
stop_words=stopwords.words('indonesian')
stop_words.extend(["yg", "dg", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh',
                       '&amp', 'yah'])

df = pd.read_csv('SW_ShopeeFood.csv', names=['stopwords']) 
stop_words.extend(df['stopwords'][0].split(' '))
stop_words = set(stop_words)

def stopwords_removal(words):
    return [word for word in words if word not in stop_words]

df['tweet_tokens_WSW'] = df['Tokenizing'].apply(stopwords_removal)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tokenizing'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import pandas as pd

factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

df = pd.read_csv("SW_ShopeeFood.csv")
df.drop(['Tokenizing'], axis=1, inplace=True)
for i, kalimat in enumerate (df['Data_Cleaning']):
    stop = stopword.remove(kalimat)

# %%
import pandas as pd
import nltk

from nltk.corpus import stopwords
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

factory = StopWordRemoverFactory()
stop_words = factory.create_stop_word_remover()

stop_words=stopwords.words('indonesian')
stop_words.extend(["yg", "dg", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh',
                       '&amp', 'yah', 'klau', 'k'])

df = pd.read_csv('SW_ShopeeFood.csv') 

df.columns = ['Tweets', 'Case_Folding', 'Data_Cleaning', 'Tokenizing']

df['without_stopwords'] = df['Data_Cleaning'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
df
# Out:
#                                                Tweets  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @Mundur41149832 shopeefood klau ngakpunya shop...
# 2   Spaghetti Aglio E Olio biasa? bukan! spaghetti...
# 3   Ngakak + malu banget, masa pesen shopeefood ki...
# 4   barangkali ada yg tinggal di sekitar daerah pa...
# ..                                                ...
# 95  Abis order shopeefood buat ortu trus mau order...
# 96  @kertas_angin @ShopeeID @shopeefood_id Trus ke...
# 97  Emg ada ya bapak bapak namanya Emma? Heran ih ...
# 98  Nasi Goreng Tiga De Nok - Palmerah sekarang ad...
# 99                 ajarin gimana cara make shopeefood
#
#                                          Case_Folding  \
# 0   2 nasi padang lauk ayam sama sayur + es teh cu...
# 1   @mundur41149832 shopeefood klau ngakpunya shop...
# 2   spaghetti aglio e olio biasa? bukan! spaghetti...
# 3   ngakak + malu banget, masa pesen shopeefood ki...
# ...
