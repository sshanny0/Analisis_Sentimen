# %%
import csv
import pandas as pd

df = pd.read_csv('dc-semua.csv') 
df
# Out:
#                                                  Tweets  \
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# 1         jangan ujan woyy shopeefood gua belom sampe 😭
# 2     Gw masih kepikiran that random cheesecake I fo...
# 3                  @urlovelymeow Coba cek di shopeefood
# 4     @wannayuuu @bdngfess Sok kirim aja kalo mau mh...
# ...                                                 ...
# 5503  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5504  Geh! Aku mau daftarin ayahku di shopeefood as ...
# 5505      alhamdulillah di rancaekek udh ada shopeefood
# 5506  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5507  @RacunBelanja https://t.co/siFXa9KDnE\n\nLumay...
#
#                                            Case_Folding  \
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# 1         jangan ujan woyy shopeefood gua belom sampe 😭
# 2     gw masih kepikiran that random cheesecake i fo...
# 3                  @urlovelymeow coba cek di shopeefood
# ...

# %%
normalizad_word = pd.read_csv('Kamus_Baku.csv')

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return ' '.join([normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document.split()])

df['Tweet_Normal'] = df['Clean_Data'].apply(normalized_term)

df
# Out:
#                                                  Tweets  \
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# 1         jangan ujan woyy shopeefood gua belom sampe 😭
# 2     Gw masih kepikiran that random cheesecake I fo...
# 3                  @urlovelymeow Coba cek di shopeefood
# 4     @wannayuuu @bdngfess Sok kirim aja kalo mau mh...
# ...                                                 ...
# 5503  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5504  Geh! Aku mau daftarin ayahku di shopeefood as ...
# 5505      alhamdulillah di rancaekek udh ada shopeefood
# 5506  Makan Gratis Bareng Teman di ShopeeFood https:...
# 5507  @RacunBelanja https://t.co/siFXa9KDnE\n\nLumay...
#
#                                            Case_Folding  \
# 0     shopeefood ini ga bisa ngasih tip buat driver ...
# 1         jangan ujan woyy shopeefood gua belom sampe 😭
# 2     gw masih kepikiran that random cheesecake i fo...
# 3                  @urlovelymeow coba cek di shopeefood
# ...

# %%
df.to_csv('normal-semua.csv',encoding='utf8', index=False)

# %%
spell = pd.read_excel('kamus.xlsx')

# make a place where we can build our new sentence
new_sentence = []

# look through each word 
for word in spell:
    # look for each candidate
    for candidate_replacement in spell:
        # if our candidate is there in the word
        if candidate_replacement in word:
            # replace it 
            word = word.replace(candidate_replacement, spell[candidate_replacement])

    # and pop it onto a new list 
    new_sentence.append(word)

rfrm = " ".join(new_sentence)
print(rfrm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10736/594633969.py in <module>
#      11         if candidate_replacement in word:
#      12             # replace it
# ---> 13             word = word.replace(candidate_replacement, spell[candidate_replacement])
#      14
#      15     # and pop it onto a new list
#
# TypeError: replace() argument 2 must be str, not Series

# %%
import pandas as pd 
import re
import nltk

def load_data():
    data = pd.read_csv('SW_ShopeeFood_D.csv')
    return data

tweet_df = load_data()

df  = pd.DataFrame(tweet_df[['Tweets', 'Case_Folding', 'Data_Cleaning', 'without_stopwords', 'Tokenizing']])
datasets = [df]

# %%
import pandas as pd 
import re
import nltk

def convertToSlangword(review):
    kamus_slangword = pd.read_csv('Kamus_Baku.csv') # Membuka dictionary slangword
    pattern = re.compile(r'\b( ' + '|'.join (kamus_slangword.keys())+r')\b') # Search pola kata (contoh kpn -> kapan)
    content = []
    review = content
    return review

# %%
data = pd.read_csv('SW_ShopeeFood_D.csv', encoding='latin-1')
# Keeping only the neccessary columns
datasets = [data]

for teks in datasets:
    teks = teks.apply(convertToSlangword)
    teks = teks.apply(" ".join)
    print(teks)
# Out:
# Tweets
# Case_Folding
# Data_Cleaning
# without_stopwords
# Tokenizing
# dtype: object
