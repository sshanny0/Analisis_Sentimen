# %%
import tweepy
from tweepy import OAuthHandler
import re
import csv

# %%
api_key = "qubRP6d5B5eCD3RHrgoMRkDjH"
api_secret_key = "AJlk1MiHfXqnhByWtCf1Mbi2T9WGW08hoLkkDIbks4ztUpFx99"
access_token ="3180202308-DmrgiSoxUUoSRevLLPldgCE57M0eD117K0mhFG5"
access_token_secret = "fuY5Hkk838OnmGOZUb16KLkSDw3JZjflxXQ1NHP6pP9Jr"

# %%
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret) 
api = tweepy.API(auth, wait_on_rate_limit = True)

# %%
# Open/create a file to append data to
csvFile = open('crawling-2-shopeefood.csv', 'w', encoding='utf-8')
#Use csv writer
csvWriter = csv.writer(csvFile)

# %%
i=1
for tweet in tweepy.Cursor(api.search_tweets, q='shopeefood -filter:retweets', tweet_mode='extended',lang="id", count="1000"):
    text = tweet.full_text
    created = tweet.created_at
    print(str(i) +')'+ tweet.full_text + '\n')
    i=i+1
    csvWriter.writerow([created, text.encode('utf-8')])
    csvWriter = csv.writer(csvFile)

# %%
hasil = api.user_timeline(screen_name="shopeefood_id", count=100, tweet_mode="extended")

# %%
for tweet in hasil:
    tweet_properties = {}
    tweet_properties["tanggal"] = tweet.created_at
    tweet_properties["user"] = tweet.user.user_timeline
    tweet_properties["tweet"] = tweet.full_text
    clean = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.full_text).split())
    print(clean)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8968/4224285154.py in <module>
#       2     tweet_properties = {}
#       3     tweet_properties["tanggal"] = tweet.created_at
# ----> 4     tweet_properties["user"] = tweet.user.user_timeline
#       5     tweet_properties["tweet"] = tweet.full_text
#       6     clean = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.full_text).split())
#
# AttributeError: 'User' object has no attribute 'user_timeline'

# %%
print("dari TXT:\n")
i=1
for tweet in hasil[:100]:
    print(str(i) +')'+ tweet.full_text + '\n')
    i=i+1
# Out:
# dari TXT:
#
# 1)Mimin ada triknya nih, ajak aja temen kamu! Biar bisa memenuhi minimum order promo ShopeeFood! Jadi tetep dapet hematnya kaaan?
#
# Coba mention temen yang mau kamu ajak jajan bareng hari ini, yuk!👇 https://t.co/GSpuGh1az4
#
# 2)Kamu tau gak yang bikin Senin jadi penuh semangat?
#
# Jawabannya baca di kata pertama xixixiii
#
# 3)Kamu pernah gak sih, gagal pake promo ShopeeFood gara-gara belum memenuhi minimal pembelian?
#
# 4)"Aku jarang sih pake ShopeeFood."
#
# 🚩🚩🚩🚩🚩🚩🚩🚩🚩🚩
#
# 5)Buat yang mau, bisa langsung cek IG ShopeeFood yaa, dijamin gak nyesel😉💛
#
# https://t.co/8bvJUNRHnD
#
# 6)Mimin hari ini punya tebak-tebakan berhadiah loh, ada yang mau?
#
# 7)Buat kalian yang belom pernah cobain ShopeeFood, mendingan langsung aja deh pesen ShopeeFood sekarang juga karena ada DISKON 100% buat ALL NEW USER. Kalo udah cobain, jangan lupa share ke mimin yaa ~
#
# 8)Aku pas denger beli ShopeeFood ada Diskon 100%: https://t.co/rKkq4nqPI3
#
# 9)@Dwi94181651 HAHAHA bisaaaa
#
# 10)Definisi cape tapi seneng:
#
# Nungguin temen milih ShopeeFood sampe berjam-jam, untung pas nyampe rasanya kaya surga.
#
# 11)Udah jgn terlalu buru-buru deketin doi. Inget kata Abang ShopeeFood...
#
# 12)Kamu tau gak kalau hari ini itu Hari Telur Sedunia?
# Coba kasih tau Mimin telur mana yang lebih cocok buat lengkapin nasi gorengmu!
#
# 13)Capek-capek nabung, ternyata ShopeeFood ada Diskon Dahsyat 60%
#
# 14)Nih yang mau promo yuk nonton Segmen Spesial ShopeeFood di 10.10 TV Show
# Pk. 19.40 - 19.43,kalian bisa dapet Paket Voucher ShopeeFood senilai 500RB hanya dengan Rp1 looh ~
#
# Buruan pasang alarm &amp; taro di kalendar kalian yaa, ShopeeFoodies! https://t.co/7i3BNnZkY6
#
# 15)Siapa yang mau promo ShopeeFood? Absen dulu dongg ~
#
# 16)Daripada capek-capek ngitungin kalori, nih mimin udah kumpulin menu-menu sehat buat ShopeeFoodies! Cuusss langsung klik https://t.co/QNj2mS1wWM yaa ~
#
# 17)Siapa yang kalo mau makan, ngitungin kalori dulu kaya gini? https://t.co/O3YvaM5BmR
#
# 18)📢 10 OKTOBER BAKAL ADA SHOPEEFOOD 10.10 TV SHOW 📢
#
# Pasang alarm kamu dari sekarang kamu bisa beli Voucher ShopeeFood 500RB cuma 1 Rupiah + dapetin EKSTRA DISKON 25RB, lhooo~* 🤩
#
# Eits, ada grand prize Toyota Innova jugaaa lho. Jgn sampai kelewatan, yaa!
#
# *Kuota voucher terbatas https://t.co/3cHuGczz1H
#
# 19)@isararisa1 Daripada ngantuk mending order ShopeeFood ya wak ;)
#
# 20)@_dianp_ Jangan sedih-sedih dong kakkk kan Mimin jd ikutan sedih :(
#
# 21)Tiga emot pertamamu menggambarkan moodmu hari Senin ini:
#
# Mimin: 😁🥣😋
#
# 22)ShopeeFoodies di Manado, penantianmu sudah berakhir! Sekarang ShopeeFood udah hadir di Manado, lhooo~ 🥰
#
# Yuk, pesen ShopeeFood pertamamu sekarang juga! Nikmati DISKON 50% + GRATIS ONGKIR SEPUASNYA.
#
# #ShopeeFoodDiManaMana https://t.co/vxbKQdCwiD
#
# 23)ShopeeFoodies yg ado di Palembang! Sekarang kamu udah bisa nikmatin ShopeeFood, lho! 😍
#
# Yuk, pesen ShopeeFood sekarang! Jangan lupa pakai DISKON 50% + GRATIS ONGKIR SEPUASNYA yaaa!
#
# #ShopeeFoodDiManaMana https://t.co/CEAe4Exg3W
#
# 24)ShopeeFoodies yang ada di Makassar, mari merapaaaat! ShopeeFood udah ada di kota kamu, lhooo~ 🥳
#
# Makan apa aja, bisa pesen di ShopeeFood! Ada DISKON 50% + GRATIS ONGKIR SEPUASNYA. Cusss, buka ShopeeFood di aplikasi Shopee kamu sekarang!
#
# #ShopeeFoodDiManaMana https://t.co/Hm2KXfZICk
#
# 25)PENGUMUMAN! ShopeeFood udah ada di Medan lohh! Mana nih suaranya warga Medan? ~
