# %%
import tweepy
from tweepy import OAuthHandler
import csv
import pandas as pd

# %%
api_key = "qubRP6d5B5eCD3RHrgoMRkDjH"
api_secret_key = "AJlk1MiHfXqnhByWtCf1Mbi2T9WGW08hoLkkDIbks4ztUpFx99"
access_token ="3180202308-DmrgiSoxUUoSRevLLPldgCE57M0eD117K0mhFG5"
access_token_secret = "fuY5Hkk838OnmGOZUb16KLkSDw3JZjflxXQ1NHP6pP9Jr"

# %%
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret) 
API = tweepy.API(auth, wait_on_rate_limit = False)

# %%
posts = tweepy.Cursor(API.search_tweets, q='syopifud -filter:retweets', tweet_mode='extended',lang="id").items(100)

# %%
users = [[tweet.created_at, tweet.full_text] for tweet in posts]
users
# Out:
# [[datetime.datetime(2021, 11, 13, 8, 19, 29, tzinfo=datetime.timezone.utc),
#   '@laedynoir Di tempatmu belum ada syopifud kaaah? :('],
#  [datetime.datetime(2021, 11, 13, 5, 56, 20, tzinfo=datetime.timezone.utc),
#   'gregetan banget syopifud makdi, minimal 40k baru dapet diskon sdgkn harga mealnya 33k udah include minuman sm eskrim 😭😭😭 nanggung amat sie'],
#  [datetime.datetime(2021, 11, 13, 5, 37, 10, tzinfo=datetime.timezone.utc),
#   '@laedynoir Tadi aku baru liat di syopifud ada sih ternyata. :D'],
#  [datetime.datetime(2021, 11, 13, 5, 21, 23, tzinfo=datetime.timezone.utc),
#   '@FOOD_FESS Blm ada syopifud😭'],
#  [datetime.datetime(2021, 11, 13, 4, 21, 7, tzinfo=datetime.timezone.utc),
#   '@bstradam_ @jogmfs ehem mas2 syopifud'],
#  [datetime.datetime(2021, 11, 13, 3, 55, 24, tzinfo=datetime.timezone.utc),
#   'Bisa nyobain kuliner umkm sekitaran tanpa harus keluar rumah, dan ga bikin dompet menangis yg pasti. I love syopifud 😻😂😅'],
#  [datetime.datetime(2021, 11, 13, 1, 56, 15, tzinfo=datetime.timezone.utc),
#   'Mau sarapan nanggung banget bentar lagi ke kantor. Entar lah syopifud aja di kantor.'],
#  [datetime.datetime(2021, 11, 13, 1, 31, 6, tzinfo=datetime.timezone.utc),
#   '-rek kalo kalian suka bgt pesen makanan lewat ojol, diskon nya yang oke mending grabfud atau syopifud?'],
#  [datetime.datetime(2021, 11, 12, 21, 24, 20, tzinfo=datetime.timezone.utc),
#   'semoga kamu nemu diskonan best deal di gofud/syopifud, semoga kamu dan crush cepet jadian, semoga kamu nggak perlu ke bioskop/museum/bazar sendirian, semoga nama kamu nggak ditunjuk dosen buat jawab pertanyaan pas kamu lagi nggak prepared'],
#  [datetime.datetime(2021, 11, 12, 16, 54, 51, tzinfo=datetime.timezone.utc),
#   '@nvjaemine syopifud ya?'],
#  [datetime.datetime(2021, 11, 12, 13, 5, 25, tzinfo=datetime.timezone.utc),
#   'gaes mau nanya 🥺 kalo mau batalin syopifud, spay nya bakal balik lg nggak ya? 🥺'],
#  [datetime.datetime(2021, 11, 12, 12, 46, 44, tzinfo=datetime.timezone.utc),
#   'Jajan syopifud teroossss'],
#  [datetime.datetime(2021, 11, 12, 12, 46, 43, tzinfo=datetime.timezone.utc),
#   '@callmenduts Aku cuma pake voucher voucher syopifud aja seh. Klo yg seribu ya gatau jg 😳'],
#  [datetime.datetime(2021, 11, 12, 12, 40, 27, tzinfo=datetime.timezone.utc),
#   'Syopifud driver nya pada kemana nih gada yang mau ngambil sad'],
#  [datetime.datetime(2021, 11, 12, 12, 32, 42, tzinfo=datetime.timezone.utc),
#   'Baeseungmin kalo jd driver syopifud https://t.co/9ciuXbkuvc'],
#  [datetime.datetime(2021, 11, 12, 12, 28, 13, tzinfo=datetime.timezone.utc),
#   'drtd msh nyari driver huhu ayo mamang syopifud diambil yu aku pgn dimsum bgt😭😭 https://t.co/6MMcZaxC2B'],
#  [datetime.datetime(2021, 11, 12, 12, 14, 41, tzinfo=datetime.timezone.utc),
#   'terpujilah mas/mba syopifud yang mau ambil orderan hujan-hujan gini...\npasti ga cuman aku yg menggigil dan enter wind di cuaca kayak begini 😭'],
#  [datetime.datetime(2021, 11, 12, 11, 21, 26, tzinfo=datetime.timezone.utc),
#   'Baru kali ini beli makan di syopifud pesenanku kuranggg. Mau marahhhh:('],
#  [datetime.datetime(2021, 11, 12, 10, 22, 25, tzinfo=datetime.timezone.utc),
#   'Kak syopifud q kejebak di veteran,,, macyet,,, https://t.co/DJRpz3xweB'],
#  [datetime.datetime(2021, 11, 12, 9, 10, 1, tzinfo=datetime.timezone.utc),
#   'Oyi saran lapak salad buah yang rekomen dong di grabfud/gofud/syopifud. Suwun rek'],
#  [datetime.datetime(2021, 11, 12, 7, 22, 12, tzinfo=datetime.timezone.utc),
#   '@kuecubityummy "kopinya kak kopinyaaaaa"\ntu syopifud lu yg ngomong'],
#  [datetime.datetime(2021, 11, 12, 7, 10, 12, tzinfo=datetime.timezone.utc),
#   '@eiine Gilak sih syopifud,cinta bangett🥺'],
#  [datetime.datetime(2021, 11, 12, 6, 20, 20, tzinfo=datetime.timezone.utc),
#   '@larasjeann Memang syopifud paling keren'],
#  [datetime.datetime(2021, 11, 12, 4, 26, 23, tzinfo=datetime.timezone.utc),
#   '@jogmfs nyantol ni barusan syopifud. tak suruh neduh dulu kalau hujan, eh bapaknya malah semangat banget. katanya demi konsumen😭😭'],
#  [datetime.datetime(2021, 11, 12, 4, 25, 28, tzinfo=datetime.timezone.utc),
#   '@eoriin huhu aku cuma punya syopifud huhu'],
#  [datetime.datetime(2021, 11, 12, 4, 2, 7, tzinfo=datetime.timezone.utc),
#   'Voucher syopifud cuma bisa dipake 1x sehari ya guis ? Mau pesen makanan untuk sekarang sama nanti siang pakai voucher hikz takut gabisa :('],
#  [datetime.datetime(2021, 11, 11, 17, 2, 1, tzinfo=datetime.timezone.utc),
#   'godaan pesan syopifud semakin besar🙂 https://t.co/xzh4Zkiuam'],
#  [datetime.datetime(2021, 11, 11, 14, 19, 24, tzinfo=datetime.timezone.utc),
#   'Syopifud ancen terbaik. Ndang onok di probolinggo wes, isok e mek pas mbalek malang tok :('],
#  [datetime.datetime(2021, 11, 11, 14, 13, 20, tzinfo=datetime.timezone.utc),
#   'Monangessss pesen makan di syopifud dari setengah 9 ga dpt driver loading terus. Trus ke gofud,yg dipengenin ga buka. Eh ke grabfud malah pesen nasi babi tore🤣🤣🤣😭 padahal awalnya cuma pengen nasgor krengsengan 23rb ajaaa malah babi tore 65rb😭🤦\u200d♀️'],
#  [datetime.datetime(2021, 11, 11, 13, 55, 16, tzinfo=datetime.timezone.utc),
#   'Morgans kebab deket kosan rame betul sama ojol2, apalagi syopifud wkwk'],
#  [datetime.datetime(2021, 11, 11, 13, 38, 30, tzinfo=datetime.timezone.utc),
#   'hdh hdh banyak promo tp app nya lag mulu wkkw buka syopifud aj lama bnr hhhh'],
#  [datetime.datetime(2021, 11, 11, 13, 29, 14, tzinfo=datetime.timezone.utc),
#   'Hari hari ditolak syopifud 😤'],
#  [datetime.datetime(2021, 11, 11, 13, 12, 55, tzinfo=datetime.timezone.utc),
#   'kebiasaan bgt deh kaka gau kalo beli gofud atau syopifud ga bilang orang rumah. kan kalo gt jadi gatau boleh langsung makan apa engga'],
#  [datetime.datetime(2021, 11, 11, 13, 12, 23, tzinfo=datetime.timezone.utc),
#   'Si dimas iki endeell puooooll keakean polaahh\n\nBtw mas jamal dah makan blm? Syopifud lg diskon banyak mas https://t.co/HTij19v7io'],
#  [datetime.datetime(2021, 11, 11, 13, 11, 6, tzinfo=datetime.timezone.utc),
#   'syopifud overload kyknya nih'],
#  [datetime.datetime(2021, 11, 11, 12, 49, 46, tzinfo=datetime.timezone.utc),
#   'Pesen burger bangor di syopifud udah mau 1.5jam ga dateng2, kesian drivernya nunggu lamaa :('],
#  [datetime.datetime(2021, 11, 11, 12, 48, 51, tzinfo=datetime.timezone.utc),
#   '@isuchae order gofud / syopifud aja'],
#  [datetime.datetime(2021, 11, 11, 12, 41, 54, tzinfo=datetime.timezone.utc),
#   'syopifud kenapa si coq, aku order makan udah hampir 2 jam gaada yang mau pickup, deket padhal. laperr 😭'],
#  [datetime.datetime(2021, 11, 11, 11, 51, 35, tzinfo=datetime.timezone.utc),
#   'Emang yang paling enak tuh ya ditraktir hehe alhamdulillah gajadi keluar uang buat jajan walaupun promo syopifud menggiurkan~'],
#  [datetime.datetime(2021, 11, 11, 11, 47, 22, tzinfo=datetime.timezone.utc),
#   '@leleliauw syopifud banyak promo kak'],
#  [datetime.datetime(2021, 11, 11, 11, 44, 40, tzinfo=datetime.timezone.utc),
#   'Aku gatau mau beli apa daripada nyari2 yauda syopifud aja😀 lumayan ni voucher 70% + gratis ongkir ahahah mwahh https://t.co/HxILBQCipV'],
#  [datetime.datetime(2021, 11, 11, 11, 17, 4, tzinfo=datetime.timezone.utc),
#   '@winchivaaree1 gass kak di syopifud'],
#  [datetime.datetime(2021, 11, 11, 11, 9, 14, tzinfo=datetime.timezone.utc),
#   '@gdluckcongrats syopifud ca wkwk sudaah yaa semangat !!'],
#  [datetime.datetime(2021, 11, 11, 11, 5, 2, tzinfo=datetime.timezone.utc),
#   'kenapaa di jember gada syopifud'],
#  [datetime.datetime(2021, 11, 11, 10, 40, 28, tzinfo=datetime.timezone.utc),
#   '@belommikirin Pake syopifud yaaa ih mawww'],
#  [datetime.datetime(2021, 11, 11, 10, 2, 59, tzinfo=datetime.timezone.utc),
#   'Mengapa yaa suamiku pandai kali dia dalam menemukan makanan enak dan murah di gofud atau syopifud, kok aku indak pandai dalam hal macam itu🥲🥲🥲\n\nTerimakasih pak suami❤'],
#  [datetime.datetime(2021, 11, 11, 9, 15, 56, tzinfo=datetime.timezone.utc),
#   'Ini silahkan yg mo promo syopifud https://t.co/mGl29wmyat'],
#  [datetime.datetime(2021, 11, 11, 8, 57, 28, tzinfo=datetime.timezone.utc),
#   'gue nungguin ini ready stock di syopifud sama di gofud LAMAAAA bgt. tapi worth it banget gue nungguin lama 🥰😻 https://t.co/qIZ2z83wlr'],
#  [datetime.datetime(2021, 11, 11, 8, 36, 28, tzinfo=datetime.timezone.utc),
#   '@vganitas Betul. Abis gini masih pengen jajan syopifud 🙂'],
#  [datetime.datetime(2021, 11, 11, 8, 6, 15, tzinfo=datetime.timezone.utc),
#   '@gawlgadoet pke syopifud aja'],
#  [datetime.datetime(2021, 11, 11, 7, 48, 45, tzinfo=datetime.timezone.utc),
#   '@aldistadiva Dikirimin syopifud haha'],
#  [datetime.datetime(2021, 11, 11, 7, 38, 34, tzinfo=datetime.timezone.utc),
#   'tadi pesen syopifud dapet driver cewe eh yg nganter si cewe tp diboncengin cowo, kayanya mereka pacaran deh ko gemes lucu 😭'],
#  [datetime.datetime(2021, 11, 11, 7, 29, 51, tzinfo=datetime.timezone.utc),
#   '@sbyfess Aku ket mau yo scroll syopifud tp gak ndang di co 🤣'],
#  [datetime.datetime(2021, 11, 11, 7, 27, 14, tzinfo=datetime.timezone.utc),
#   'babi ini syp yg pesen syopifud ke alamat rumahku'],
#  [datetime.datetime(2021, 11, 11, 7, 22, 50, tzinfo=datetime.timezone.utc),
#   'Tadi lama nungguin syopifud ga dapet² drivernya, eh pas nyoba gr4b langsung dapet wkw mayan buat makan siang - makan malem jog , selamat makan! https://t.co/lgaGYWTmRd'],
#  [datetime.datetime(2021, 11, 11, 7, 2, 53, tzinfo=datetime.timezone.utc),
#   'Udah gini masih pengen syopifud. 💔💔💔💔 https://t.co/SSWXNF9tWU'],
#  [datetime.datetime(2021, 11, 11, 6, 39, 31, tzinfo=datetime.timezone.utc),
#   'order syopifud 3x gofud 3x gadapet” driver. aku sabar 🥲'],
#  [datetime.datetime(2021, 11, 11, 6, 23, 11, tzinfo=datetime.timezone.utc),
#   'syopifud emg paling lancar bikin miskin, ada diskon 11.11 70% sampe 35rb yakali ga jajan 😭😭'],
#  [datetime.datetime(2021, 11, 11, 6, 14, 55, tzinfo=datetime.timezone.utc),
#   'gw lupa ada kelas gara2 drtd mantengin syopifud'],
#  [datetime.datetime(2021, 11, 11, 6, 2, 11, tzinfo=datetime.timezone.utc),
#   'Dari tadi mesen syopifud ga ada driver yg ngambil :"'],
#  [datetime.datetime(2021, 11, 11, 6, 0, 5, tzinfo=datetime.timezone.utc),
#   'Jog ada yg bisa mesen syopifud ga e? Ini aku dari tadi order drivernya ga ngambil² :"'],
#  [datetime.datetime(2021, 11, 11, 5, 57, 13, tzinfo=datetime.timezone.utc),
#   'ni syopifud gada yg mau pick up w laper ajg'],
#  [datetime.datetime(2021, 11, 11, 5, 53, 1, tzinfo=datetime.timezone.utc),
#   '@DarkestEspresso syopifud bakar duit 💸💸💸'],
#  [datetime.datetime(2021, 11, 11, 5, 52, 50, tzinfo=datetime.timezone.utc),
#   'syopifud aing lama bgt yaallah nyasar apa abangnya'],
#  [datetime.datetime(2021, 11, 11, 5, 47, 4, tzinfo=datetime.timezone.utc),
#   'Jog syopifud dan gofud ga ada yg mau ngambil ya ini? :('],
#  [datetime.datetime(2021, 11, 11, 5, 35, 27, tzinfo=datetime.timezone.utc),
#   'HBNGGGG kenapa ga nemu driver syopifud 😔😔😔😔😔😔 sy laper tak tertolong'],
#  [datetime.datetime(2021, 11, 11, 5, 17, 34, tzinfo=datetime.timezone.utc),
#   'eh anjg napa ini syopifud nya gaada peomo😂'],
#  [datetime.datetime(2021, 11, 11, 5, 7, 3, tzinfo=datetime.timezone.utc),
#   'makanan wajib kalo di sini. cumi telur asin 🤤 ini + nasgor omelette + bengbeng panas pake syopifud jadi 23rb tp ini gw gadapet bembengnya tp gpp sih soalnya beli itu biar nyampe minimal pembelian biar diskon :D https://t.co/aCmxLbeASr'],
#  [datetime.datetime(2021, 11, 11, 4, 39, 21, tzinfo=datetime.timezone.utc),
#   'Ni org nahan² jajan merch biar bisa nabung LAH MALAH BABLAS JAJAN DI SYOPIFUD\n\nDahlah'],
#  [datetime.datetime(2021, 11, 11, 4, 23, 28, tzinfo=datetime.timezone.utc),
#   '@jogmfs scroll syopifud'],
#  [datetime.datetime(2021, 11, 11, 3, 24, 3, tzinfo=datetime.timezone.utc),
#   'Wkwkw gws orang2 yg order makanan lewat syopifud padahal masih segedung cuman beda lantai doang https://t.co/yupaxNLgef'],
#  [datetime.datetime(2021, 11, 11, 2, 38, 56, tzinfo=datetime.timezone.utc),
#   '@jogmfs hujan nder coba syopifud'],
#  [datetime.datetime(2021, 11, 11, 2, 29, 22, tzinfo=datetime.timezone.utc),
#   '11.11 saatnya menjelajahi syopifud gofud grabfud'],
#  [datetime.datetime(2021, 11, 10, 18, 0, 36, tzinfo=datetime.timezone.utc),
#   '11.11 ku nge syopifud bubur ketan hitam'],
#  [datetime.datetime(2021, 11, 10, 15, 40, 45, tzinfo=datetime.timezone.utc),
#   'Gara gara lu gua jadi ikutan jajan di syopifud, Rae 😀👍🏾 https://t.co/bT22RCNUxR https://t.co/hPcZgzK6ot'],
#  [datetime.datetime(2021, 11, 10, 15, 16, 26, tzinfo=datetime.timezone.utc),
#   'jooheon: punten, syopifud https://t.co/erpQYFRSuU'],
#  [datetime.datetime(2021, 11, 10, 15, 3, 26, tzinfo=datetime.timezone.utc),
#   'Diem dulu dong w lg fokus scroll syopifud makanan buat sahur @OfficialMonstaX'],
#  [datetime.datetime(2021, 11, 10, 14, 54, 53, tzinfo=datetime.timezone.utc),
#   '@Jowooshen Kabayang mun aya nu mantuna jiga johnny uhh geus pamer daa 🥲 “bu ieu mantu abdi tepangkeun” “alah meni kasep kieu orang mana kasep” ahh lieur weh pokokna\nTah asli, tapi teu boga duit oge bisa ngegas ngan nya teu bisa syopifud weh 😩'],
#  [datetime.datetime(2021, 11, 10, 14, 26, 56, tzinfo=datetime.timezone.utc),
#   '@rememorari Waduh brarti serangan syopifud ngaruh bgt ya.....'],
#  [datetime.datetime(2021, 11, 10, 14, 21, 30, tzinfo=datetime.timezone.utc),
#   '@alamortlaf biar dpt promo ga sih, syopifud bnyk promonya 😔'],
#  [datetime.datetime(2021, 11, 10, 13, 20, 46, tzinfo=datetime.timezone.utc),
#   'Semangat pak driver syopifud yang lagi ujan2 gini tetep nerima orderan 💕💕💕'],
#  [datetime.datetime(2021, 11, 10, 12, 20, 51, tzinfo=datetime.timezone.utc),
#   '@jaemcityx aku mauuu makji mau syopifud&lt;3'],
#  [datetime.datetime(2021, 11, 10, 11, 44, 40, tzinfo=datetime.timezone.utc),
#   '@abiwn Iya itu misal kan dipukul rata per orderan ongkir 6ribuan, dan resto yg bayar parkir. Belum pengeluaran bensin, makan, rokok. Itu juga itungan 15x, soalnya kek aku aja skrg kalo libur kerja kadang on syopifud narik 11-12x tuh kerasa cape'],
#  [datetime.datetime(2021, 11, 10, 11, 25, 28, tzinfo=datetime.timezone.utc),
#   'ngidam mie ayam banget tapi dicancel sama babang syopifud 🥲'],
#  [datetime.datetime(2021, 11, 10, 10, 59, 4, tzinfo=datetime.timezone.utc),
#   'Krn takut nanti hujan lagi jd sengaja order syopifud dan drivernya sopan bgt, ga nunda waktu sholat juga~ semoga lancar rezekinya ya mas, sll diberikan kesehatan &amp; keselamatan 🙏🏻 aamiin https://t.co/NQXw7III72'],
#  [datetime.datetime(2021, 11, 10, 10, 58, 31, tzinfo=datetime.timezone.utc),
#   'aku, setiap beli gacoan di syopifud https://t.co/BRyr4g6z1H'],
#  [datetime.datetime(2021, 11, 10, 10, 33, 51, tzinfo=datetime.timezone.utc),
#   'Me @ diskon syopifud https://t.co/pxOL0AQgly'],
#  [datetime.datetime(2021, 11, 10, 9, 3, 53, tzinfo=datetime.timezone.utc),
#   'Menunggu abang syopifud...'],
#  [datetime.datetime(2021, 11, 10, 8, 50, 39, tzinfo=datetime.timezone.utc),
#   'syopifud di lampung servicenya masih lama nggak ya? maksudnya deliverynya dll gitu'],
#  [datetime.datetime(2021, 11, 10, 8, 46, 56, tzinfo=datetime.timezone.utc),
#   'Guis disini ada yg dom Semarang, dan pake syopifud ngga? yg udh ga pake gofud/grab lagi. aku mau tanya tanyaa'],
#  [datetime.datetime(2021, 11, 10, 8, 46, 47, tzinfo=datetime.timezone.utc),
#   'fess disini ada yg dom Semarang, dan pake syopifud ngga? yg udh ga pake gofud/grab lagi. aku mau tanya tanyaa'],
#  [datetime.datetime(2021, 11, 10, 8, 29, 9, tzinfo=datetime.timezone.utc),
#   'Berhentilahh hujann anj, aku belum makan. Kasian aku dari tadi bolak balik buka menu syopifud :)'],
#  [datetime.datetime(2021, 11, 10, 7, 50, 16, tzinfo=datetime.timezone.utc),
#   'Pengin cilor tapi di syopifud sm gojek ga adaaa :('],
#  [datetime.datetime(2021, 11, 10, 6, 10, 28, tzinfo=datetime.timezone.utc),
#   'Syopifud tuh mesti pinpoint lokasi sendiri apa ya.. alamatnya bener tapi suka salah pinpoint-nya haduh 😔 untung drivernya inisiatif chat WA tadi.\nKebiasaan pake ijo jadi lupa mulu sama ini'],
#  [datetime.datetime(2021, 11, 10, 4, 8, 32, tzinfo=datetime.timezone.utc),
#   '@fahrifaisaal Syopifud frey. Biasalah pengguna baru wkwkwk. Klik dulu link aku atuh meh didinya bisa pake voucher'],
#  [datetime.datetime(2021, 11, 10, 3, 36, 11, tzinfo=datetime.timezone.utc),
#   'Buka syopi rencananya mau syopifud. Tp knp akhirnya jd checkout night cream 😮'],
#  [datetime.datetime(2021, 11, 10, 1, 14, 42, tzinfo=datetime.timezone.utc),
#   'crazy, baru pertama pake syopifud lgsg terlena dengan diskon dan gratis ongkir https://t.co/bBIgZtnIYZ'],
#  [datetime.datetime(2021, 11, 9, 17, 6, 50, tzinfo=datetime.timezone.utc),
#   '@almiracalista8 @anstaDew @AbangojolBOTak Iya Syopifud lagi oke emang promonya. And langsung sampe depan rumah, ngeh rumahku yang mana karena drivernya baca Notes 👌🏽'],
#  [datetime.datetime(2021, 11, 9, 15, 40, 12, tzinfo=datetime.timezone.utc),
#   '@convomf apsi ajg, di syopifud noh banyak promo, beli sendiri, jan kek org susah'],
#  [datetime.datetime(2021, 11, 9, 15, 34, 26, tzinfo=datetime.timezone.utc),
#   'agak panik freeong ga keapply ternyata belum ganti alamat habis ngirim syopifud temen']]

# %%
df = pd.DataFrame(data=users, columns=['Created_At','Tweets'])
df
# Out:
#                   Created_At  \
# 0  2021-11-13 08:19:29+00:00
# 1  2021-11-13 05:56:20+00:00
# 2  2021-11-13 05:37:10+00:00
# 3  2021-11-13 05:21:23+00:00
# 4  2021-11-13 04:21:07+00:00
# ..                       ...
# 95 2021-11-10 03:36:11+00:00
# 96 2021-11-10 01:14:42+00:00
# 97 2021-11-09 17:06:50+00:00
# 98 2021-11-09 15:40:12+00:00
# 99 2021-11-09 15:34:26+00:00
#
#                                                Tweets
# 0   @laedynoir Di tempatmu belum ada syopifud kaaa...
# 1   gregetan banget syopifud makdi, minimal 40k ba...
# 2   @laedynoir Tadi aku baru liat di syopifud ada ...
# 3                        @FOOD_FESS Blm ada syopifud😭
# 4               @bstradam_ @jogmfs ehem mas2 syopifud
# ..                                                ...
# 95  Buka syopi rencananya mau syopifud. Tp knp akh...
# 96  crazy, baru pertama pake syopifud lgsg terlena...
# 97  @almiracalista8 @anstaDew @AbangojolBOTak Iya ...
# 98  @convomf apsi ajg, di syopifud noh banyak prom...
# 99  agak panik freeong ga keapply ternyata belum g...
#
# [100 rows x 2 columns]

# %%
df.to_csv('crawling-5-syopifud.csv')
