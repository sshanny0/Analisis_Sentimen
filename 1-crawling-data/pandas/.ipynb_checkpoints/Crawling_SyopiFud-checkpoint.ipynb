# %%
import tweepy
from tweepy import OAuthHandler
import csv
import pandas as pd

# %%
api_key = "qubRP6d5B5eCD3RHrgoMRkDjH"
api_secret_key = "AJlk1MiHfXqnhByWtCf1Mbi2T9WGW08hoLkkDIbks4ztUpFx99"
access_token ="3180202308-DmrgiSoxUUoSRevLLPldgCE57M0eD117K0mhFG5"
access_token_secret = "fuY5Hkk838OnmGOZUb16KLkSDw3JZjflxXQ1NHP6pP9Jr"

# %%
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret) 
API = tweepy.API(auth, wait_on_rate_limit = False)

# %%
posts = tweepy.Cursor(API.search_tweets, q='syopifud -filter:retweets', tweet_mode='extended',lang="id").items(500)

# %%
users = [[tweet.created_at, tweet.full_text] for tweet in posts]
users
# Out:
# [[datetime.datetime(2021, 10, 28, 6, 6, 20, tzinfo=datetime.timezone.utc),
#   'abang abang syopifud di semarang lagi pada wfh\n\nwork from hell alias semarang panas e koyo neroko jancok'],
#  [datetime.datetime(2021, 10, 28, 4, 36, 42, tzinfo=datetime.timezone.utc),
#   'Jd temen w tuh driver baru syopifud nah kemarin minta bantuan revisi laporan trus tbtb doi on aplikasinya dah tau ya kl on app malem2 pasti tetep dapet orderan tp doi ga percaya anjer wkwk eh taunya bener ada orderan masuk mana laporan dia blm selese direvisi semua, trus jd buru2'],
#  [datetime.datetime(2021, 10, 28, 4, 25, 41, tzinfo=datetime.timezone.utc),
#   'Gegara syopifud w jajan terosss 🥲'],
#  [datetime.datetime(2021, 10, 28, 2, 59, 7, tzinfo=datetime.timezone.utc),
#   'lol akunku diblokir beneran gara2 penyalahgunaan vocer syopifud😂😂😂😂😂😂😂🙂🙂🙂🙂'],
#  [datetime.datetime(2021, 10, 28, 2, 31, 10, tzinfo=datetime.timezone.utc),
#   '@maspras_ Semoga bisa dapet, soalnya mau dipake buat pengaktifan akun syopifud biar bisa ngojek lg 🙂'],
#  [datetime.datetime(2021, 10, 28, 2, 27, 12, tzinfo=datetime.timezone.utc),
#   'beli bakso porsi lengkap + kikil di tambah es degan jumbo cuma 11k\nsyopifud ai lop yu dehhh https://t.co/lNBPgDtcuy'],
#  [datetime.datetime(2021, 10, 27, 18, 36, 42, tzinfo=datetime.timezone.utc),
#   'Dah kaya syopifud yaa kak meng https://t.co/BmmRmHvck8'],
#  [datetime.datetime(2021, 10, 27, 17, 1, 18, tzinfo=datetime.timezone.utc),
#   '@elcaeera syopifud deh pasti bisa!'],
#  [datetime.datetime(2021, 10, 27, 15, 44, 40, tzinfo=datetime.timezone.utc),
#   'Baru kali ini gw pesan makanan resto lewat syopifud dapat sadfood. Padahal bintangnya 4,7 banyak disukai. Pas datang, loh penampilannya kayak abang2 keliling, rasanya hambar, nasinya rada kering. Malah lebih enak abang2 keliling, porsi banyak, komplit pke acar n krupuk,hrg murah.'],
#  [datetime.datetime(2021, 10, 27, 15, 31, 7, tzinfo=datetime.timezone.utc),
#   '@nyahyuck Ini punyakuuu mana punyamu 🥰🥰🥰\n\nKok sama sih pesennya pake syopifud https://t.co/ud87SlumTA'],
#  [datetime.datetime(2021, 10, 27, 14, 12, 3, tzinfo=datetime.timezone.utc),
#   'kerja di syopi bagian syopifud, my responsibility is klaim voucher plus checkout makanan 😭👍🏻🙏🏻'],
#  [datetime.datetime(2021, 10, 27, 13, 54, 34, tzinfo=datetime.timezone.utc),
#   'Bahaya bgt ini di kost bareng adek, jadi jajan syopifud terus ampe pen gumoh sendiri liat makanan. Mana kembung aer😭'],
#  [datetime.datetime(2021, 10, 27, 13, 4, 54, tzinfo=datetime.timezone.utc),
#   'Giliran dah di ibu kota, ujan muluuuu. Ampe mau pesen syopifud ga tega💔'],
#  [datetime.datetime(2021, 10, 27, 12, 1, 40, tzinfo=datetime.timezone.utc),
#   '@Unsoedfess1963 Pada pindah syopifud kak'],
#  [datetime.datetime(2021, 10, 27, 11, 56, 48, tzinfo=datetime.timezone.utc),
#   'Ujan weeee.. syopifud aja susah kali jdnya 😔'],
#  [datetime.datetime(2021, 10, 27, 11, 56, 17, tzinfo=datetime.timezone.utc),
#   '-dips! rekomen makan malem yg ada di syopifud dong'],
#  [datetime.datetime(2021, 10, 27, 11, 4, 29, tzinfo=datetime.timezone.utc),
#   'Giliran dapet vocher syopifud, ga pengen jajan apa2 🙂👍'],
#  [datetime.datetime(2021, 10, 27, 10, 57, 37, tzinfo=datetime.timezone.utc),
#   'sumpah sy team syopifud rn,banyak diskon njems😼😽💘'],
#  [datetime.datetime(2021, 10, 27, 9, 59, 29, tzinfo=datetime.timezone.utc),
#   '@mrnatasya meanwhile kita disebelahnya mesen syopifud voucher 70%'],
#  [datetime.datetime(2021, 10, 27, 9, 28, 36, tzinfo=datetime.timezone.utc),
#   '@gombang Syopifud'],
#  [datetime.datetime(2021, 10, 27, 8, 22, 25, tzinfo=datetime.timezone.utc),
#   'Syopifud sampe kapan bakar duit? Beli chatime 2, 51 rb, bayar cuma 20rb 🥲🥲'],
#  [datetime.datetime(2021, 10, 27, 8, 21, 16, tzinfo=datetime.timezone.utc),
#   '@FOOD_FESS Aku skrg lebih sering pake syopifud'],
#  [datetime.datetime(2021, 10, 27, 8, 16, 4, tzinfo=datetime.timezone.utc),
#   'fess disini ada yg pake syopifud ngga? yg udh ga pake gofud/grab lagi. aku mau tanya tanyaa'],
#  [datetime.datetime(2021, 10, 27, 8, 15, 44, tzinfo=datetime.timezone.utc),
#   'guis disini ada yg pake syopifud ngga? yg udh ga pake gofud/grab lagi. aku mau tanya tanyaa'],
#  [datetime.datetime(2021, 10, 27, 8, 15, 35, tzinfo=datetime.timezone.utc),
#   'ndes disini ada yg pake syopifud ngga? yg udh ga pake gofud/grab lagi. aku mau tanya tanyaa'],
#  [datetime.datetime(2021, 10, 27, 7, 0, 33, tzinfo=datetime.timezone.utc),
#   'The Breeze udah ada Subway tapi belum nongol di gofud atau syopifud. Kapan-kapan aja lah.. Males antri.'],
#  [datetime.datetime(2021, 10, 27, 4, 15, 28, tzinfo=datetime.timezone.utc),
#   'Hidup di kampung malah jatohnya lebih mahal. Ga ada promo syopifud atau gofud wkwkwk'],
#  [datetime.datetime(2021, 10, 27, 4, 11, 59, tzinfo=datetime.timezone.utc),
#   'Bisa makan siang cm 3rb rupiah. 🤣 Terima kasih syopifud 💖'],
#  [datetime.datetime(2021, 10, 27, 2, 12, 41, tzinfo=datetime.timezone.utc),
#   '@FOOD_FESS ada kok dlu aku beli di syopifud, cuma kan jam segini masih menu breakfast nder jadi ga muncul tar agak siangan cek lagi'],
#  [datetime.datetime(2021, 10, 27, 2, 12, 20, tzinfo=datetime.timezone.utc),
#   'Fess di syopifud emang ga ada paketan buat dapet botol minum mukidi kah? https://t.co/o3pRs7yRAY'],
#  [datetime.datetime(2021, 10, 27, 2, 11, 10, tzinfo=datetime.timezone.utc),
#   'Guis di syopifud emang ga ada paketan buat dapet botol minum mukidi kah? https://t.co/9rPbP3NdPW'],
#  [datetime.datetime(2021, 10, 26, 16, 46, 44, tzinfo=datetime.timezone.utc),
#   'sumpah ms gue beli kwetiau sm es jeruk di syopifud cuma 13k?!?!'],
#  [datetime.datetime(2021, 10, 26, 14, 57, 20, tzinfo=datetime.timezone.utc),
#   'Dinas di daerah terisolir dan gada gofud n syopifud bikin kangen rumah sangat'],
#  [datetime.datetime(2021, 10, 26, 14, 56, 52, tzinfo=datetime.timezone.utc),
#   'sedih bgt w pesen tomyam di syopifud trus minta tolong abangnya cantelin gerbang trs pas keluar gak ada:))))))))))'],
#  [datetime.datetime(2021, 10, 26, 14, 28, 43, tzinfo=datetime.timezone.utc),
#   'Nungguin ada syopifud di kotaku eh pas ada taunya promonya ga se wow di kota lain... Malah mendingan grebgo nya huhu sebel'],
#  [datetime.datetime(2021, 10, 26, 14, 8, 20, tzinfo=datetime.timezone.utc),
#   '@fforfvck Syopifud emng gaada obat'],
#  [datetime.datetime(2021, 10, 26, 13, 10, 10, tzinfo=datetime.timezone.utc),
#   '@UNSfess_ Kalo lagi ujan emang gitu nder, pake syopifud aja'],
#  [datetime.datetime(2021, 10, 26, 12, 46, tzinfo=datetime.timezone.utc),
#   'AKHIRNYA DI KOTA KU ADA SYOPIFUD HUHUU'],
#  [datetime.datetime(2021, 10, 26, 12, 30, 26, tzinfo=datetime.timezone.utc),
#   'syopifud lamalama meresahkan grgr disc 18rb:)'],
#  [datetime.datetime(2021, 10, 26, 12, 18, 57, tzinfo=datetime.timezone.utc),
#   'eh tp gue kalo beli nasi kulit ini selalu banyak😂 mana murah kalo pake syopifud wkwkw  tergantung store keknya https://t.co/QB1v73gWk0 https://t.co/pI7JRz0EFr'],
#  [datetime.datetime(2021, 10, 26, 11, 25, 14, tzinfo=datetime.timezone.utc),
#   'Lup syopifud https://t.co/RMrxevGveT'],
#  [datetime.datetime(2021, 10, 26, 9, 43, 53, tzinfo=datetime.timezone.utc),
#   '21k aja untuk kopirum dan croffle sinamon tengs syopifud https://t.co/M698vBm4wJ'],
#  [datetime.datetime(2021, 10, 26, 9, 34, 28, tzinfo=datetime.timezone.utc),
#   '@friendofxanax @byisahustlerr astaghfirullah ini promo pengguna baru syopifud. 🥲'],
#  [datetime.datetime(2021, 10, 26, 9, 24, 38, tzinfo=datetime.timezone.utc),
#   'Bodo bener gw jir, checkout syopifud lupa masukin voucher gratong\nBerasa rugi banget 10 ribu buat ongkir doang..'],
#  [datetime.datetime(2021, 10, 26, 7, 40, 45, tzinfo=datetime.timezone.utc),
#   '@Ikencupang Syopifud adalah jalan ninjaku wkwk'],
#  [datetime.datetime(2021, 10, 26, 7, 4, 50, tzinfo=datetime.timezone.utc),
#   '@babugembul sleman mbaaa, samping amikom wkwkwk enak pas itu aku beli syopifud sih'],
#  [datetime.datetime(2021, 10, 26, 6, 50, 19, tzinfo=datetime.timezone.utc),
#   'syopifud dari gerlong ke bekasi bisa gak ya'],
#  [datetime.datetime(2021, 10, 26, 6, 35, 42, tzinfo=datetime.timezone.utc),
#   'promo syopifud membuatku ingin makan gacoan tiap hari😌🙏🏻'],
#  [datetime.datetime(2021, 10, 26, 6, 27, 54, tzinfo=datetime.timezone.utc),
#   'Anjer gw bikin telor ceplok aja ga enak, dah lah kapok mau syopifud aja'],
#  [datetime.datetime(2021, 10, 26, 6, 12, 43, tzinfo=datetime.timezone.utc),
#   'Kalo pingin makan makanan yg emg agak pricy selagi ada di syopifud knp harus dinein sih😂😂'],
#  [datetime.datetime(2021, 10, 26, 6, 7, 24, tzinfo=datetime.timezone.utc),
#   'Syopifud for lyfe, penolong isi dompet akhir bulan.'],
#  [datetime.datetime(2021, 10, 26, 5, 58, 55, tzinfo=datetime.timezone.utc),
#   '@lamekairtas Knp ya disini gabisa syopifud?'],
#  [datetime.datetime(2021, 10, 26, 5, 5, 16, tzinfo=datetime.timezone.utc),
#   'syopifud udh ada di ta6, tapi bentar ahh jajannya mingdep aja soalnya aku lagi kere'],
#  [datetime.datetime(2021, 10, 26, 3, 34, 30, tzinfo=datetime.timezone.utc),
#   'kalau di sini makannya dibackup sama syopifud 😂🔥'],
#  [datetime.datetime(2021, 10, 26, 3, 15, 8, tzinfo=datetime.timezone.utc),
#   '@carameluckyy aku pake syopifud aman aman aja cya, kok bisa ke ban sih akunmu 😭'],
#  [datetime.datetime(2021, 10, 26, 2, 10, 37, tzinfo=datetime.timezone.utc),
#   'olive apa tida mau expand ke syopifud'],
#  [datetime.datetime(2021, 10, 25, 18, 24, 43, tzinfo=datetime.timezone.utc),
#   'Kayaknya malem ini orang” pada kelaperan, mesen di syopifud udah 4 resto sibuk gara” keramean pesenan. Btw aku yo luwe'],
#  [datetime.datetime(2021, 10, 25, 12, 42, 9, tzinfo=datetime.timezone.utc),
#   '@lovingMahaec RA ITU ADA SI SYOPIFUD GAKKK'],
#  [datetime.datetime(2021, 10, 25, 10, 51, 23, tzinfo=datetime.timezone.utc),
#   '@sipvalen_ Syopifud bole nda? Mau makan berdua sm papah https://t.co/st9NgzZ4fx'],
#  [datetime.datetime(2021, 10, 25, 10, 45, 8, tzinfo=datetime.timezone.utc),
#   'tinggal jemput aja lewat grabfud, gofud dan syopifud. Thank you 🙏'],
#  [datetime.datetime(2021, 10, 25, 10, 37, 10, tzinfo=datetime.timezone.utc),
#   '@sunglightyear geprek mozza pak goo di syopifud kalo menurut gw enak enak aja sih, standar lah yaa'],
#  [datetime.datetime(2021, 10, 25, 10, 30, 21, tzinfo=datetime.timezone.utc),
#   'gue asal mau syopifud milih mau beli apanya sejam-an trs akhirnya gjd beli :)'],
#  [datetime.datetime(2021, 10, 25, 10, 1, 30, tzinfo=datetime.timezone.utc),
#   'makasi syopifud https://t.co/Sfw8HaPhxY'],
#  [datetime.datetime(2021, 10, 25, 8, 19, 13, tzinfo=datetime.timezone.utc),
#   'Moots! Mau wtt dana ke spay dong 3.5k no tipu tipu yaa😖 mo co syopifud ni🤧'],
#  [datetime.datetime(2021, 10, 25, 8, 2, 44, tzinfo=datetime.timezone.utc),
#   '@lixstraykids @FOODFESS2 dari syopifud nya -ns'],
#  [datetime.datetime(2021, 10, 25, 7, 39, 38, tzinfo=datetime.timezone.utc),
#   'kenapaa promo2 gofud syopifud gabisa bayar tunaii😭'],
#  [datetime.datetime(2021, 10, 25, 7, 9, 14, tzinfo=datetime.timezone.utc),
#   '@anothernaside HSHSHSHSH itu bukannya tiap hari di syopifud ya apa di grab ini?'],
#  [datetime.datetime(2021, 10, 25, 7, 7, 29, tzinfo=datetime.timezone.utc),
#   'Ngerasa bersalah banget kalau driver minta biaya parkir terus kubilang nanti diganti pake fitur tip. Giliran dah beres tinggal ngerating trs malah gagal ngasih tipnya 🥲\n\nPiye iki syopifud.'],
#  [datetime.datetime(2021, 10, 25, 5, 44, 35, tzinfo=datetime.timezone.utc),
#   'beli makan pake syopifud kece uga. potongannya banyak'],
#  [datetime.datetime(2021, 10, 25, 5, 34, 19, tzinfo=datetime.timezone.utc),
#   'Guis pada jajan apa nih di syopifud? Mumpung diskon 70%😍 https://t.co/rZ6ZoUkv8o'],
#  [datetime.datetime(2021, 10, 25, 5, 8, 55, tzinfo=datetime.timezone.utc),
#   '@kanyamary @ogiehart Mba nya cantikk Dressnya mera menyala seperti spicy wontonku... yuk yang jogja di order ada di greb gofud dan syopifud https://t.co/K9vLYO5BgV'],
#  [datetime.datetime(2021, 10, 25, 5, 3, 52, tzinfo=datetime.timezone.utc),
#   'Kok kalo dibandingin di jekardah malah mahalan makan via syopifud di jogja ya dengan promo yg sama. Disana &lt;20k bisa makan nasi ayam 2x anjir'],
#  [datetime.datetime(2021, 10, 25, 4, 45, 1, tzinfo=datetime.timezone.utc),
#   'ak juga maw vocer syopifud😭😭'],
#  [datetime.datetime(2021, 10, 25, 1, 20, 6, tzinfo=datetime.timezone.utc),
#   '@Rainal_705 Spay biar bisa beli sarapan di syopifud'],
#  [datetime.datetime(2021, 10, 25, 0, 52, 15, tzinfo=datetime.timezone.utc),
#   'syopifud ada diskon 70% max 35rb lagi guysssss\nrekomendasi makan siang donggg wkwkwkwkw'],
#  [datetime.datetime(2021, 10, 24, 22, 2, 25, tzinfo=datetime.timezone.utc),
#   'rekomen sushi yg ena di syopifud ? ndes'],
#  [datetime.datetime(2021, 10, 24, 16, 42, 27, tzinfo=datetime.timezone.utc),
#   'Kebiasaan baru adek gue jam segini adalah order syopifud'],
#  [datetime.datetime(2021, 10, 24, 15, 21, 38, tzinfo=datetime.timezone.utc),
#   'Kalo temenku trial error mpasi, kalo kita kata @novindpra trial error voucher syopifud, grepfud, dan gofud 🥲'],
#  [datetime.datetime(2021, 10, 24, 14, 9, 8, tzinfo=datetime.timezone.utc),
#   '@Varputra ujung2nya beli gopud / syopifud dlu biar cepet milih tontonan. krn aku klo makan pasti sambil nonton 😂😂'],
#  [datetime.datetime(2021, 10, 24, 13, 30, 24, tzinfo=datetime.timezone.utc),
#   '@SetengahBangun "Hadeuh" - driver syopifud'],
#  [datetime.datetime(2021, 10, 24, 12, 4, 50, tzinfo=datetime.timezone.utc),
#   '@chrislinow yuyuyuu pesen syopifud'],
#  [datetime.datetime(2021, 10, 24, 12, 4, 40, tzinfo=datetime.timezone.utc),
#   '@vanestayz hooh, yg di syopifud tapii'],
#  [datetime.datetime(2021, 10, 24, 11, 17, 23, tzinfo=datetime.timezone.utc),
#   'Lucunya waktu ditotal bisa lebih murah dr warteg deket tempat kerja (emang agak mahal di sana) \n\nMemang voucher diskon penyelamat wkwk semua aku pakein dr mulai gr4b, syopifud, tr4veloka 😂'],
#  [datetime.datetime(2021, 10, 24, 10, 42, 50, tzinfo=datetime.timezone.utc),
#   'Namanya sumoyaki, pesennya di syopifud, cuman 22k isi 15 aww ✨ enak kok ga kalah sama gindaco https://t.co/nNiiALYcPf https://t.co/QLh7VWoulu'],
#  [datetime.datetime(2021, 10, 24, 10, 40, 10, tzinfo=datetime.timezone.utc),
#   'Ini gak ada yg mau trade? Pengen order syopifud'],
#  [datetime.datetime(2021, 10, 24, 10, 5, 18, tzinfo=datetime.timezone.utc),
#   '@rentfess tadi abang syopifud yg anter kopi aku ternyata udah pernah pick up orderan aku 3kali dalam minggu ini'],
#  [datetime.datetime(2021, 10, 24, 9, 44, 10, tzinfo=datetime.timezone.utc),
#   '@day6confess pertama tama mau sungkem dulu selanjutnya "kita enaknya gofud, grabfud apa syopifud ya?"'],
#  [datetime.datetime(2021, 10, 24, 9, 38, 1, tzinfo=datetime.timezone.utc),
#   'Sempet kaget akun syopi bodongan gw ampe diblokir padal ga pernah dipinjem²in ato dipake jualan jg.. ternyata kena pelanggaran promo syopifud gegara order mixue 2x berturut².. krik krik deh 😑🤌🏻'],
#  [datetime.datetime(2021, 10, 24, 8, 16, 11, tzinfo=datetime.timezone.utc),
#   'ya Allah gue kalo ditanyain patokan rumah langsung jadi bodoh banget, maaf ya mas mas syopifud 🙏'],
#  [datetime.datetime(2021, 10, 24, 7, 33, 58, tzinfo=datetime.timezone.utc),
#   'pwk kagak ada syopifud sad 😭'],
#  [datetime.datetime(2021, 10, 24, 5, 9, 59, tzinfo=datetime.timezone.utc),
#   '@RacunBelanja Sayangnya di domku gada syopifud😭'],
#  [datetime.datetime(2021, 10, 24, 2, 43, 31, tzinfo=datetime.timezone.utc),
#   'lho udah buka deket sini tapi gaada di syopifud :('],
#  [datetime.datetime(2021, 10, 24, 2, 17, 36, tzinfo=datetime.timezone.utc),
#   '@jessiclown_ Promo syopifud lebi bikin gagal diet gasii 😭'],
#  [datetime.datetime(2021, 10, 23, 23, 55, 39, tzinfo=datetime.timezone.utc),
#   'nasi kuning gerobakan gt ada di syopifud gayaa hmm'],
#  [datetime.datetime(2021, 10, 23, 23, 16, 40, tzinfo=datetime.timezone.utc),
#   '@paypamuntjak pake syopifud loh mas 20k bayar mek 10k kadang 9k kalo harga makane pas 20k'],
#  [datetime.datetime(2021, 10, 23, 18, 12, 58, tzinfo=datetime.timezone.utc),
#   'pas nyari di syopifud keluarnya ‘pala ayam’'],
#  [datetime.datetime(2021, 10, 23, 14, 21, 14, tzinfo=datetime.timezone.utc),
#   'Harapanku di tahun 2021 ada syopifud di Kediri biar vocer ak ga mubadzir :('],
#  [datetime.datetime(2021, 10, 23, 13, 43, 10, tzinfo=datetime.timezone.utc),
#   'Segini di syopifud jadi 29 ribu https://t.co/D1N7KULcrz'],
#  [datetime.datetime(2021, 10, 23, 13, 1, 4, tzinfo=datetime.timezone.utc),
#   'gmas yh @spharitxe y nnti aq syopifud in hri jumat y klaw adh duit😢😢 https://t.co/SA6v18IOWI'],
#  [datetime.datetime(2021, 10, 23, 12, 58, 34, tzinfo=datetime.timezone.utc),
#   'Kerjaan kk gue make syopifud mulu yg satu lg demennya gofud pas nyampe abangnya bareng lgsung akward anjer😭'],
#  [datetime.datetime(2021, 10, 23, 12, 15, tzinfo=datetime.timezone.utc),
#   'benter mo isya dl sembari menunggu syopifud'],
#  [datetime.datetime(2021, 10, 23, 11, 38, 51, tzinfo=datetime.timezone.utc),
#   '@favakyou syopifud biar murah👩\u200d🦲'],
#  [datetime.datetime(2021, 10, 23, 11, 27, 33, tzinfo=datetime.timezone.utc),
#   '#OREO YaAllah beli syopifud udah sejam ngga nyampe-nyampe, bapaknya nyasar kemana-mana😑👎🏻'],
#  [datetime.datetime(2021, 10, 23, 9, 47, 59, tzinfo=datetime.timezone.utc),
#   '@savanazz_ "nasikatsu" di syopifud'],
#  [datetime.datetime(2021, 10, 23, 8, 57, 30, tzinfo=datetime.timezone.utc),
#   '@loveseskrim syopifud ajaaa coba sheiii'],
#  [datetime.datetime(2021, 10, 23, 5, 8, 54, tzinfo=datetime.timezone.utc),
#   '@jinkasperr syopifud mantep 12k dpt 2'],
#  [datetime.datetime(2021, 10, 23, 1, 42, 39, tzinfo=datetime.timezone.utc),
#   '@yogurtgreenF syopifud lbh bakar duit kak woakwoa'],
#  [datetime.datetime(2021, 10, 22, 17, 11, 46, tzinfo=datetime.timezone.utc),
#   'valid bgt dah sumpah senior asso w kalo ngitung splitbill gofud atau syopifud sampe dibuat wp nya😭👍🏻\n\ndulu pas dikirimin wp split bill sampe kena culture shock dalem hati "DIA NGIRIM WP APAAAA INI?!!!" wkwkwk🥲😭😂 https://t.co/eVUy8rZ1Es'],
#  [datetime.datetime(2021, 10, 22, 14, 30, 30, tzinfo=datetime.timezone.utc),
#   'syopifud adalah jalan ninjaku'],
#  [datetime.datetime(2021, 10, 22, 13, 9, 47, tzinfo=datetime.timezone.utc),
#   'Syopifud membantu sekali ternyata'],
#  [datetime.datetime(2021, 10, 22, 12, 44, 16, tzinfo=datetime.timezone.utc),
#   'Pesen syopifud, ternyata restonya deket banget ga sampe 300m dari kosan wkwkwk.'],
#  [datetime.datetime(2021, 10, 22, 12, 26, 35, tzinfo=datetime.timezone.utc),
#   '@FWBESS Syopifud ada potongan 25k nder td gw beli makan 2 porsi totalnya jd 18k kok. Info ajasi'],
#  [datetime.datetime(2021, 10, 22, 9, 57, 12, tzinfo=datetime.timezone.utc),
#   'Syopifud cocok bgt buat aku https://t.co/j7x1a4OSII'],
#  [datetime.datetime(2021, 10, 22, 9, 37, 55, tzinfo=datetime.timezone.utc),
#   '@Fahroe03 Kalo syopifud bingung, gak tau selera makan yg gimana wkwk kayaknya emang kudu ditelusuri makanan yg biasa mereka makan'],
#  [datetime.datetime(2021, 10, 22, 8, 54, 28, tzinfo=datetime.timezone.utc),
#   '@FOOD_FESS heuheu aku pake syopifud jadi 27 :D'],
#  [datetime.datetime(2021, 10, 22, 7, 9, 24, tzinfo=datetime.timezone.utc),
#   '@04JAEMIN LHO IYA wkwkwk kirain syopifud ih aku juga abis gofood tp gada diskon:")'],
#  [datetime.datetime(2021, 10, 22, 7, 2, 42, tzinfo=datetime.timezone.utc),
#   '@04JAEMIN Meng iri ga ada syopifud disinii'],
#  [datetime.datetime(2021, 10, 22, 5, 13, 40, tzinfo=datetime.timezone.utc),
#   "terima kasih untuk bapak syopifud yang tidak pernah jemu mengantar makanan disaat kerjaan saya tidak bisa ditinggal:') untuk syopi juga karena berkat anda saya bisa makan bergizi dengan budget minimum tanpa harus keluar rumah🥺🙏🏻"],
#  [datetime.datetime(2021, 10, 22, 5, 8, 15, tzinfo=datetime.timezone.utc),
#   'Ini mas syopifud kok ga gerak2 ya :( dichat ceklis satu :(( huhu gimana dong :(( dikit lagi ada kelas :('],
#  [datetime.datetime(2021, 10, 22, 2, 17, 46, tzinfo=datetime.timezone.utc),
#   'Baru tadi ada si ibu kamar ujung ngasih nasi uduk buat makan siang karena kasian lihat gue gapernah keliatan makan siang kali ya (tp bener sih) 🥲\n\nSebelumnya dikasih sosis goreng + nugget banyak. Katanya karena gue udah ngasih tau tempat buat beli gas dan tips syopifud 😭'],
#  [datetime.datetime(2021, 10, 21, 17, 10, 16, tzinfo=datetime.timezone.utc),
#   'Syopifud sahabat anak kos https://t.co/ziilJbf3Cf'],
#  [datetime.datetime(2021, 10, 21, 17, 9, 13, tzinfo=datetime.timezone.utc),
#   '@dulcetyoongi_ Iyaaa ini ketemu di syopifud. soalnya beneran susah yg biasa 24 jam sekarang jd ngga lagii'],
#  [datetime.datetime(2021, 10, 21, 16, 52, 19, tzinfo=datetime.timezone.utc),
#   'laper mau pesen syopifud eh pada tutup jam 12'],
#  [datetime.datetime(2021, 10, 21, 13, 40, 42, tzinfo=datetime.timezone.utc),
#   'finally wkwkwk tp aku maunya mas2 syopifud yg di jogja hehe https://t.co/RjLOZqNtaP'],
#  [datetime.datetime(2021, 10, 21, 13, 30, 45, tzinfo=datetime.timezone.utc),
#   'eh anjir syopifud promonya banyak bgt gue shock?????'],
#  [datetime.datetime(2021, 10, 21, 13, 8, 5, tzinfo=datetime.timezone.utc),
#   'Pesen syopifud terus abangnya nganter pesenan sambil boncengan ma pacarnya hahahaha'],
#  [datetime.datetime(2021, 10, 21, 12, 59, 50, tzinfo=datetime.timezone.utc),
#   'YaAllah seneng banget gue kalo nemu makanan di syopifud yang ternyata enak banget. 😭😭😭\n\nGue kan paling sebel kalo beli di tempat baru pertama gataunya zonk, tapi bosen kalo beli makan itu-itu aja. Makanya terharu banget kalo nemu yang enak di tempat lain tuh. 🥺'],
#  [datetime.datetime(2021, 10, 21, 10, 23, tzinfo=datetime.timezone.utc),
#   'Almet kampus sama jaket Syopifud sama persis warnanya, kalo dipake dijalan bisa mengelabuhi orang 😭'],
#  [datetime.datetime(2021, 10, 21, 10, 6, 23, tzinfo=datetime.timezone.utc),
#   '@jayareumdaun nah makanyaa sama banget semua karena syopifud:")'],
#  [datetime.datetime(2021, 10, 21, 9, 21, 1, tzinfo=datetime.timezone.utc),
#   '@blueejays iya aku mah gabakalan bisa uninst, tiap hari aku syopifud :")'],
#  [datetime.datetime(2021, 10, 21, 9, 8, 31, tzinfo=datetime.timezone.utc),
#   '@jayareumdaun mau aku unist tapi kadang promo suka menggiurkan apalagi syopifud huhuhu ")'],
#  [datetime.datetime(2021, 10, 21, 8, 14, 59, tzinfo=datetime.timezone.utc),
#   '@kookieshitaeru Kalau grabfood,gofood dan syopifud harusnya bisa kak, kecuali jaraknya kejauhan tergantung sistem aplikasinya aja'],
#  [datetime.datetime(2021, 10, 21, 6, 20, 33, tzinfo=datetime.timezone.utc),
#   'ginian doang bisa balikin mood wkwkw, btw perkara tinggal co syopifud aja mikirnya sampai setengah jam😭✊🏻 https://t.co/eW9zZg4eU2'],
#  [datetime.datetime(2021, 10, 21, 6, 14, 6, tzinfo=datetime.timezone.utc),
#   'omo omo diskon syopifud lagi'],
#  [datetime.datetime(2021, 10, 21, 6, 3, 42, tzinfo=datetime.timezone.utc),
#   'Pada bisa order syopifud ga si? Ksl bgt aku'],
#  [datetime.datetime(2021, 10, 21, 5, 15, 25, tzinfo=datetime.timezone.utc),
#   '@FOODFESS2 kenapa gaa syopifud ajaa'],
#  [datetime.datetime(2021, 10, 21, 4, 40, 22, tzinfo=datetime.timezone.utc),
#   'saranin gua syopifud apa'],
#  [datetime.datetime(2021, 10, 21, 4, 13, 5, tzinfo=datetime.timezone.utc),
#   '@pokonyakentank 15rb kak seporsi, kl di syopifud dpt diskon lg 50%plus free ongkir'],
#  [datetime.datetime(2021, 10, 21, 3, 43, 35, tzinfo=datetime.timezone.utc),
#   '@potonganbolu @jogmfs Masama kakk, fyi kl pake syopifud dapet diskon lagi 50% + free ongkir'],
#  [datetime.datetime(2021, 10, 21, 3, 40, 29, tzinfo=datetime.timezone.utc),
#   '@potonganbolu @jogmfs Tinggal order di gofud or grab or syopifud kak, namanya laperisme. Buka dari jam 3 sampe jam 9 😄'],
#  [datetime.datetime(2021, 10, 21, 3, 39, 31, tzinfo=datetime.timezone.utc),
#   '@ambar_leola Tinggal cek di grabfud, gofud or syopifud aja kak namanya laperisme. Bukanya jam 3 sampe jam 9 😄'],
#  [datetime.datetime(2021, 10, 21, 3, 36, 33, tzinfo=datetime.timezone.utc),
#   '@ambar_leola @mediocrickey 15rb kak, tp kl order di syopifud dapet diskon lagi 50% + freeongkir'],
#  [datetime.datetime(2021, 10, 20, 17, 43, 19, tzinfo=datetime.timezone.utc),
#   '@bittermuffinn aku masih nunggu kang syopifud'],
#  [datetime.datetime(2021, 10, 20, 13, 54, 42, tzinfo=datetime.timezone.utc),
#   '@marsekal_ mau syopifud apa'],
#  [datetime.datetime(2021, 10, 20, 13, 44, 32, tzinfo=datetime.timezone.utc),
#   '@geapus Kui murah banget, Ghe.... Gusti, omahku ngopo gak ke detect syopifud'],
#  [datetime.datetime(2021, 10, 20, 12, 56, 40, tzinfo=datetime.timezone.utc),
#   '@muchlovekoo lgi mau makanan apa yg ada di syopifud?'],
#  [datetime.datetime(2021, 10, 20, 11, 47, 44, tzinfo=datetime.timezone.utc),
#   'saran makanan yang ada di syopifud dong tengkyu -dips!'],
#  [datetime.datetime(2021, 10, 20, 11, 32, 59, tzinfo=datetime.timezone.utc),
#   'SYOPIFUD MKSDNYA GOBLO WKWK'],
#  [datetime.datetime(2021, 10, 20, 10, 46, 52, tzinfo=datetime.timezone.utc),
#   '@calmeasap @tubirfess Hayu kak kl dom jogja bisa diorder di grab, gofud or syopifud. Kl di luar kota bisa order fr0zennya via ig (at)laperisme'],
#  [datetime.datetime(2021, 10, 20, 10, 42, 9, tzinfo=datetime.timezone.utc),
#   '@ttxtif @kalajengqueen__ @kissingfullsun @Thankyo27858791 @tubirfess Kalo dom Jog available di gofud,grabfud dan syopifud kak, kalau non jogja bisa dm ke ig (at)laperisme'],
#  [datetime.datetime(2021, 10, 20, 10, 26, 20, tzinfo=datetime.timezone.utc),
#   '@undipmenfess Syopifud lah, ayam goreng mas londo cm 7k'],
#  [datetime.datetime(2021, 10, 20, 10, 10, 9, tzinfo=datetime.timezone.utc),
#   'Fess Spicy Chicken Wonton. 15rb aja dijamin kenyang dan senang. Homemade Pangsit ayam dengan homemade chili oil. \n\nOrder di laperisme ya, Available on Grebfud, gofud, syopifud. Dom jog https://t.co/krnXDpLmsU'],
#  [datetime.datetime(2021, 10, 20, 9, 2, 48, tzinfo=datetime.timezone.utc),
#   '@ssyylvaa lain ketang, pake syopifud'],
#  [datetime.datetime(2021, 10, 20, 6, 55, 7, tzinfo=datetime.timezone.utc),
#   '[askrl] trims syopifud, berkatmu hanya dgn 16k anak kos ini bisa makan sampe malem😭👍🏻 https://t.co/LY3z2WdxQx'],
#  [datetime.datetime(2021, 10, 20, 6, 18, 15, tzinfo=datetime.timezone.utc),
#   '@FFOODFESS bandingin sama grab syopifud dulu nderrr harganya'],
#  [datetime.datetime(2021, 10, 20, 5, 42, 39, tzinfo=datetime.timezone.utc),
#   'cb bygin syopi bs dipake utk byr ukt, dan tersedia diskon kek syopifud, gua rasa ortu gua bakal bahagia'],
#  [datetime.datetime(2021, 10, 19, 17, 27, 23, tzinfo=datetime.timezone.utc),
#   'mesen syopifud malah dicancel gitu aja sama abangnya. hiksssss mau order lagi takutttt mana yg tadi nungguinnya lama'],
#  [datetime.datetime(2021, 10, 19, 15, 55, 3, tzinfo=datetime.timezone.utc),
#   'pesen pizza biar dapet potongan syopifud'],
#  [datetime.datetime(2021, 10, 19, 14, 50, 27, tzinfo=datetime.timezone.utc),
#   '@adorabyule Pake syopifud biar untung promo malah jadi buntung WKWKWKWKWKWK'],
#  [datetime.datetime(2021, 10, 19, 14, 47, 54, tzinfo=datetime.timezone.utc),
#   'Kebodohan hari ini. Aku habis dari cafe jd alamat syopifud nya nyantol di alamat cafe itu. Aku ga cek lagi pas mau pesen dari rumah, pikirku udh otomatis huft. Aku cmn takut diomeli driver tp untungnya baik bangetttt hueee 🥺🥺🥺 https://t.co/eLIJZxrY6N'],
#  [datetime.datetime(2021, 10, 19, 13, 6, 30, tzinfo=datetime.timezone.utc),
#   'Gua liat2 mapsnya syopifud ngaco ni'],
#  [datetime.datetime(2021, 10, 19, 12, 2, 40, tzinfo=datetime.timezone.utc),
#   '@kentangkiii syopifud dong'],
#  [datetime.datetime(2021, 10, 19, 11, 58, 32, tzinfo=datetime.timezone.utc),
#   'Merasakan syopifud lebih murah drpd dateng ke tempatnya'],
#  [datetime.datetime(2021, 10, 19, 11, 57, 36, tzinfo=datetime.timezone.utc),
#   'uda hampir 3 hari ga ketemu orang langsung🙃 ambil syopifud aja \nminta dicantelin pager🙃'],
#  [datetime.datetime(2021, 10, 19, 11, 10, 57, tzinfo=datetime.timezone.utc),
#   'Grgr diskon syopifud jadi cobain circle K dan ternyata ena bgtttt 🥺 murah lagi'],
#  [datetime.datetime(2021, 10, 19, 10, 33, 41, tzinfo=datetime.timezone.utc),
#   'Syopifud mulai menurunkan promonya pelan2'],
#  [datetime.datetime(2021, 10, 19, 10, 13, 24, tzinfo=datetime.timezone.utc),
#   '@funkyykong EMANG ANJIRRR AKU KENYANG BGT BELI2 DI SYOPIFUD']]

# %%
df = pd.DataFrame(data=users, columns=['Created_At','Tweets'])
df
# Out:
#                    Created_At  \
# 0   2021-10-28 06:06:20+00:00
# 1   2021-10-28 04:36:42+00:00
# 2   2021-10-28 04:25:41+00:00
# 3   2021-10-28 02:59:07+00:00
# 4   2021-10-28 02:31:10+00:00
# ..                        ...
# 162 2021-10-19 11:58:32+00:00
# 163 2021-10-19 11:57:36+00:00
# 164 2021-10-19 11:10:57+00:00
# 165 2021-10-19 10:33:41+00:00
# 166 2021-10-19 10:13:24+00:00
#
#                                                 Tweets
# 0    abang abang syopifud di semarang lagi pada wfh...
# 1    Jd temen w tuh driver baru syopifud nah kemari...
# 2                    Gegara syopifud w jajan terosss 🥲
# 3    lol akunku diblokir beneran gara2 penyalahguna...
# 4    @maspras_ Semoga bisa dapet, soalnya mau dipak...
# ..                                                 ...
# 162  Merasakan syopifud lebih murah drpd dateng ke ...
# 163  uda hampir 3 hari ga ketemu orang langsung🙃 am...
# 164  Grgr diskon syopifud jadi cobain circle K dan ...
# 165          Syopifud mulai menurunkan promonya pelan2
# 166  @funkyykong EMANG ANJIRRR AKU KENYANG BGT BELI...
#
# [167 rows x 2 columns]

# %%
df.to_csv('crawling-2-syopifud.csv')
